# %% [markdown]
# # Creating a playing cards dataset
# This notebook is a guide through the creation of a dataset of playing cards. The cards are labeled with their name (ex: "2c" for "2 of spades", "Kh" for King for hearts) and with the bounding boxes delimiting their printed corners.
# > _Why bounding boxes around the corners, and not around the whole card ?_<br>Because in real conditions, more often than not, cards are partially covered. And the corner of a card is the minimum information you need to identify it.
#
# This dataset can be used for the training of a neural net intended to detect/localize playing cards. It was used on the project __[Playing card detection with YOLO v3](https://youtu.be/pnntrewH0xg)__
#
# <img src="img/ex_generated_image.png" alt="Example of generated image "  title="Example of generated image " />

# %% [markdown]
# # Prerequisites
#
# ### A. In addition to opencv and numpy, you need the following python packages :
# 1. **imgaug** : https://github.com/aleju/imgaug
# > Helps with image augmentation
# 2. **shapely** : https://github.com/Toblerity/Shapely
# > For the manipulation and analysis of geometric objects in the Cartesian plane. It is useful here when we want to check if the bounding box of a card corner is covered by another card
# 3. **tqdm** : https://github.com/tqdm/tqdm
# > A progress bar tool. Not mandatory but convenient when you generate thousands of images
#
# ### B. Get the Describable Textures Dataset (DTD)
# > A collection of textural images in the wild (https://www.robots.ox.ac.uk/~vgg/data/dtd/). It is probably not its original goal, but it is used here as an easy way to generate various backgrounds for our images.
#
# ### C. A real deck of cards
# > This the only physical "data" you need. You have to make some measurements on the cards, and to take a picture/shoot a movie of each of the 52 cards of the deck. Everything else will be generated by scripts.

# %% [markdown]
# #### C.1 Measurements on the cards
# Use a ruler to measure the dimensions as indicated in the image below.
# For the corner* measures, the idea is to delimit one rectangular zone that can hold every value+suit. The size of the marks may vary with the value or the suit, so take the measures on the cards with the widest, the tallest symbols, and add one or two millimeters.
# <img src="img/measures.png" alt="Measures" title="" />
# Report the measures in mm in the cell below (and don't forget to run the cell).

# %%
cardW=58
cardH=88
cornerXmin=1.5
cornerXmax=10
cornerYmin=2.5
cornerYmax=20.5

# We convert the measures from mm to pixels: multiply by an arbitrary factor 'zoom'
# You shouldn't need to change this
zoom=4
cardW*=zoom
cardH*=zoom
cornerXmin=int(cornerXmin*zoom)
cornerXmax=int(cornerXmax*zoom)
cornerYmin=int(cornerYmin*zoom)
cornerYmax=int(cornerYmax*zoom)

# %% [markdown]
# #### C.2 Shoot one video per card
# That's what I did in the project "Playing card detection with YOLO v3", and the scripts in this notebook were written to deal with videos. A video is interesting only if you can vary the brightness and color temperature of the light during the shot. Watch [Playing card detection with YOLO v3](https://www.youtube.com/watch?v=pnntrewH0xg&t=4m10s) to have an idea.
# With hindsight, I am confident that you could use one picture per card instead of a video without affecting the efficiency of the neural net. The scripts could be easily adapted to deal with pictures.
# Whether you use videos or pictures, the scene must be simple, with a uniform background behind the card, like below. This way, the extraction of the card from the scene will be easy.
# <img src="test/scene.png" alt="Scene" title="Scene" />

# %% [markdown]
# ## Imports

# %%
import numpy as np
import cv2
import os
from tqdm import tqdm
import random
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import pickle
from glob import glob 
import imgaug as ia
from imgaug import augmenters as iaa
from shapely.geometry import Polygon

# %% [markdown]
# ## Some convenient functions used in this notebook

# %%
def display_img(img,polygons=[],channels="bgr",size=9):
    """
        Function to display an inline image, and draw optional polygons (bounding boxes, convex hulls) on it.
        Use the param 'channels' to specify the order of the channels ("bgr" for an image coming from OpenCV world)
    """
    if not isinstance(polygons,list):
        polygons=[polygons]    
    if channels=="bgr": # bgr (cv2 image)
        nb_channels=img.shape[2]
        if nb_channels==4:
            img=cv2.cvtColor(img,cv2.COLOR_BGRA2RGBA)
        else:
            img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)    
    fig,ax=plt.subplots(figsize=(size,size))
    ax.set_facecolor((0,0,0))
    ax.imshow(img)
    for polygon in polygons:
        # An polygon has either shape (n,2), 
        # either (n,1,2) if it is a cv2 contour (like convex hull).
        # In the latter case, reshape in (n,2)
        if len(polygon.shape)==3:
            polygon=polygon.reshape(-1,2)
        patch=patches.Polygon(polygon,linewidth=1,edgecolor='g',facecolor='none')
        ax.add_patch(patch)

def give_me_filename(dirname, suffixes, prefix=""):
    """
        Function that returns a filename or a list of filenames in directory 'dirname'
        that does not exist yet. If 'suffixes' is a list, one filename per suffix in 'suffixes':
        filename = dirname + "/" + prefix + random number + "." + suffix
        Same random number for all the file name
        Ex: 
        > give_me_filename("dir","jpg", prefix="prefix")
        'dir/prefix408290659.jpg'
        > give_me_filename("dir",["jpg","xml"])
        ['dir/877739594.jpg', 'dir/877739594.xml']        
    """
    if not isinstance(suffixes, list):
        suffixes=[suffixes]
    
    suffixes=[p if p[0]=='.' else '.'+p for p in suffixes]
          
    while True:
        bname="%09d"%random.randint(0,999999999)
        fnames=[]
        for suffix in suffixes:
            fname=os.path.join(dirname,prefix+bname+suffix)
            if not os.path.isfile(fname):
                fnames.append(fname)
                
        if len(fnames) == len(suffixes): break
    
    if len(fnames)==1:
        return fnames[0]
    else:
        return fnames

# %% [markdown]
# # Define global variables

# %%
data_dir="data" # Directory that will contain all kinds of data (the data we download and the data we generate)

if not os.path.isdir(data_dir):
    os.makedirs(data_dir)

cards_values = ["2c","2s","4d","5d","5h","6s","7h","8c","8d","9h","10c","10s"]    

# Pickle file containing the background images from the DTD
backgrounds_pck_fn=data_dir+"/backgrounds.pck"

# Pickle file containing the card images
cards_pck_fn=data_dir+"/cards.pck"


# imgW,imgH: dimensions of the generated dataset images 
imgW=720
imgH=720


refCard=np.array([[0,0],[cardW,0],[cardW,cardH],[0,cardH]],dtype=np.float32)
refCardRot=np.array([[cardW,0],[cardW,cardH],[0,cardH],[0,0]],dtype=np.float32)
refCornerHL=np.array([[cornerXmin,cornerYmin],[cornerXmax,cornerYmin],[cornerXmax,cornerYmax],[cornerXmin,cornerYmax]],dtype=np.float32)
refCornerLR=np.array([[cardW-cornerXmax,cardH-cornerYmax],[cardW-cornerXmin,cardH-cornerYmax],[cardW-cornerXmin,cardH-cornerYmin],[cardW-cornerXmax,cardH-cornerYmin]],dtype=np.float32)
refCorners=np.array([refCornerHL,refCornerLR])

# %% [markdown]
# # Get Describable Textures Dataset (DTD)
# A convenient way to generate backgrounds for the images of the cards dataset

# %% [markdown]
# ### Download DTD (1x)

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/dtd/download/dtd-r1.0.1.tar.gz
# Out:
# 'wget' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %% [markdown]
# ### Extract the DTD (1x)

# %%
# !tar xf dtd-r1.0.1.tar.gz

# %% [markdown]
# ### Load all *jpg from dtd subdirectories and save them in a pickle file (1x)
#
# The next times, we will directly load the pickle file

# %%
dtd_dir="dtd/images/"
bg_images=[]
for subdir in glob(dtd_dir+"/*"):
    for f in glob(subdir+"/*.jpg"):
        bg_images.append(mpimg.imread(f))
print("Nb of images loaded :",len(bg_images))
print("Saved in :",backgrounds_pck_fn)
pickle.dump(bg_images,open(backgrounds_pck_fn,'wb'))
# Out:
# Nb of images loaded : 0
# Saved in : data/backgrounds.pck

# %% [markdown]
# ### Load all *png from personal background into a pickle file

# %%
dtd_dir="data/backgrounds"
bg_images=[]
for f in glob(dtd_dir+"/*.png"):
    bg_images.append(mpimg.imread(f))
print("Nb of images loaded :",len(bg_images))
print("Saved in :",backgrounds_pck_fn)
pickle.dump(bg_images,open(backgrounds_pck_fn,'wb'))
# Out:
# Nb of images loaded : 10
# Saved in : data/backgrounds.pck

# %% [markdown]
# ### Load the backgounds pickle file in 'backgrounds'
# 'backgrounds' is an instance of the class Backgrounds
# To get a random background image, call the method : backgrounds.get_random

# %%
class Backgrounds():
    def __init__(self,backgrounds_pck_fn=backgrounds_pck_fn):
        self._images=pickle.load(open(backgrounds_pck_fn,'rb'))
        self._nb_images=len(self._images)
        print("Nb of images loaded :", self._nb_images)
    def get_random(self, display=False):
        bg=self._images[random.randint(0,self._nb_images-1)]
        if display: plt.imshow(bg)
        return bg
    
backgrounds = Backgrounds()
# Out:
# Nb of images loaded : 10

# %%
# Test: display a random background
_=backgrounds.get_random(display=True)

# %% [markdown]
# # Extraction of the cards from pictures or video

# %% [markdown]
# ### Define the alphamask
# The alphamask has 2 purposes:
# - clean the border of the detected cards,
# - make that border transparent. Cards are not perfect rectangles because corners are rounded. We need to make transparent the zone between the real card and its bounding rectangle, otherwise this zone will be visible in the final generated images of the dataset

# %%
bord_size=2 # bord_size alpha=0
alphamask=np.ones((cardH,cardW),dtype=np.uint8)*255
cv2.rectangle(alphamask,(0,0),(cardW-1,cardH-1),0,bord_size)
cv2.line(alphamask,(bord_size*3,0),(0,bord_size*3),0,bord_size)
cv2.line(alphamask,(cardW-bord_size*3,0),(cardW,bord_size*3),0,bord_size)
cv2.line(alphamask,(0,cardH-bord_size*3),(bord_size*3,cardH),0,bord_size)
cv2.line(alphamask,(cardW-bord_size*3,cardH),(cardW,cardH-bord_size*3),0,bord_size)
plt.figure(figsize=(10,10))
plt.imshow(alphamask)

# %% [markdown]
# ## Function extract_card
# Extract from scene image (cv2/bgr) the part corresponding to the card and transforms it
# to fit into the reference card shape.
# We suppose here that the user facilitates as much as he can the extraction task by
# making the scene image simple (one card on uniform backgroung, not too blurry, correct lighting,...)

# %%
def varianceOfLaplacian(img):
    """
    Compute the Laplacian of the image and then return the focus
    measure, which is simply the variance of the Laplacian
    Source: A.Rosebrock, https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/
    """
    return cv2.Laplacian(img, cv2.CV_64F).var()

def extract_card (img, output_fn=None, min_focus=39, debug=False):
    """
    """
    
    imgwarp=None
    
    # Check the image is not too blurry
    focus=varianceOfLaplacian(img)
    if focus < min_focus: 
        if debug: print("Focus too low :", focus)
        return False,None
    
    # Convert in gray color
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
    # Noise-reducing and edge-preserving filter
    gray=cv2.bilateralFilter(gray,10,10,10)
    
    # Edge extraction
    edge=cv2.Canny(gray,30,200)
    ret, bin_img  = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find the contours in the edged image
    cnts,_ = cv2.findContours(bin_img,cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    
    # We suppose that the contour with largest area corresponds to the contour delimiting the card
    cnt = sorted(cnts, key = cv2.contourArea, reverse = True)[0]
    
    # We want to check that 'cnt' is the contour of a rectangular shape
    # First, determine 'box', the minimum area bounding rectangle of 'cnt'
    # Then compare area of 'cnt' and area of 'box'
    # Both areas sould be very close
    rect=cv2.minAreaRect(cnt)
    box=cv2.boxPoints(rect)
    box=np.int0(box)
    areaCnt=cv2.contourArea(cnt)
    areaBox=cv2.contourArea(box)
    valid=areaCnt/areaBox>0.95
    
    if valid:
        # We want transform the zone inside the contour into the reference rectangle of dimensions (cardW,cardH)
        ((xr,yr),(wr,hr),thetar)=rect
        # Determine 'Mp' the transformation that transforms 'box' into the reference rectangle
        if wr>hr:
            Mp=cv2.getPerspectiveTransform(np.float32(box),refCard)
        else:
            Mp=cv2.getPerspectiveTransform(np.float32(box),refCardRot)
        # Determine the warped image by applying the transformation to the image
        imgwarp=cv2.warpPerspective(img,Mp,(cardW,cardH))
        # Add alpha layer
        imgwarp=cv2.cvtColor(imgwarp,cv2.COLOR_BGR2BGRA)
        
        # Shape of 'cnt' is (n,1,2), type=int with n = number of points
        # We reshape into (1,n,2), type=float32, before feeding to perspectiveTransform
        cnta=cnt.reshape(1,-1,2).astype(np.float32)
        # Apply the transformation 'Mp' to the contour
        cntwarp=cv2.perspectiveTransform(cnta,Mp)
        cntwarp=cntwarp.astype(np.int)
        
        # We build the alpha channel so that we have transparency on the
        # external border of the card
        # First, initialize alpha channel fully transparent
        alphachannel=np.zeros(imgwarp.shape[:2],dtype=np.uint8)
        # Then fill in the contour to make opaque this zone of the card 
        cv2.drawContours(alphachannel,cntwarp,0,255,-1)
        
        # Apply the alphamask onto the alpha channel to clean it
        alphachannel=cv2.bitwise_and(alphachannel,alphamask)
        
        # Add the alphachannel to the warped image
        imgwarp[:,:,3]=alphachannel
        
        # Save the image to file
        if output_fn is not None:
            cv2.imwrite(output_fn,imgwarp)
        
    if debug:
        cv2.imshow("Gray",gray)
        cv2.imshow("Canny",edge)
        edge_bgr=cv2.cvtColor(edge,cv2.COLOR_GRAY2BGR)
        cv2.drawContours(edge_bgr,[box],0,(0,0,255),3)
        cv2.drawContours(edge_bgr,[cnt],0,(0,255,0),-1)
        cv2.imshow("Contour with biggest area",edge_bgr)
        if valid:
            cv2.imshow("Alphachannel",alphachannel)
            cv2.imshow("Extracted card",imgwarp)

    return valid,imgwarp

# %%
# Test on one image
debug=True
img=cv2.imread("data/cards_image/6s.jpeg")
display_img(img)
valid,card=extract_card(img,"data/extracted_card.png", debug=False)
if valid:
    display_img(card)
if debug:
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# ## Function extract_cards_from_video

# %%
def extract_cards_from_video(video_fn, output_dir=None, keep_ratio=5, min_focus=29, debug=False):
    """
        Extract cards from media file 'video_fn' 
        If 'output_dir' is specified, the cards are saved in 'output_dir'.
        One file per card with a random file name
        Because 2 consecutives frames are probably very similar, we don't use every frame of the video, 
        but only one every 'keep_ratio' frames
        
        Returns list of extracted images
    """
    if not os.path.isfile(video_fn):
        print(f"Video file {video_fn} does not exist !!!")
        return -1,[]
    if output_dir is not None and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    cap=cv2.VideoCapture(video_fn)
    
    frame_nb=0
    imgs_list=[]
    while True:
        ret,img=cap.read()
        if not ret: break
        # Work on every 'keep_ratio' frames
        if frame_nb%keep_ratio==0:
            if output_dir is not None:
                output_fn=give_me_filename(output_dir,"png")
            else:
                output_fn=None
            valid,card_img = extract_card(img,output_fn,min_focus=min_focus,debug=debug)
            print(valid)
            if debug: 
                k=cv2.waitKey(1)
                if k==27: break
            if valid:
                imgs_list.append(card_img)
        frame_nb+=1
    
    if debug:
        cap.release()
        cv2.destroyAllWindows()
    
    return imgs_list

# %%
# Test card extraction from a video   
imgs=extract_cards_from_video("test/2c.avi",output_dir="test/2c",debug=True)
print("Nb images extracted:",len(imgs))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Nb images extracted: 15

# %% [markdown]
# # Card extraction from all the videos
# We suppose we have for each card_name (ex: 2d, Kc, Ah) one video file named 'card_name.extension' (ex: 2d.avi, Kc.avi, Ah.avi) in a common directory (ex: data/video). If you use images instead of movies, the script below should work by setting the variable 'extension' below to "jpg" or "png".
# The cards from a video, or the card from an image, will be extracted in a subdirectory named 'card_name' placed in the directory 'imgs_dir' (ex: data/cards)

# %%
video_dir="data/cards_image"
extension="jpeg"
imgs_dir="data/cards"

for card_name in cards_values:
        
        video_fn=os.path.join(video_dir,card_name+"."+extension)
        output_dir=os.path.join(imgs_dir,card_name)
        if not os.path.isdir(output_dir):
            os.makedirs(output_dir)
        imgs=extract_cards_from_video(video_fn,output_dir)
        print("Extracted images for %s : %d"%(card_name,len(imgs)))
# Out:
# True
# Extracted images for 2c : 1
# True
# Extracted images for 2s : 1
# True
# Extracted images for 4d : 1
# True
# Extracted images for 5d : 1
# True
# Extracted images for 5h : 1
# True
# Extracted images for 6s : 1
# True
# Extracted images for 7h : 1
# True
# Extracted images for 8c : 1
# True
# Extracted images for 8d : 1
# True
# Extracted images for 9h : 1
# True
# Extracted images for 10c : 1
# True
# Extracted images for 10s : 1

# %% [markdown]
# ## Augment data set using imgaug

# %%
imgs_dir="data/cards"

seq = iaa.Sequential([
    iaa.GaussianBlur(sigma=(0, 4)), # blur images with a sigma of 0 to 2.0
])
aug = iaa.Multiply((0.5, 1.8))

for card_name in cards_values:
        img_dir=os.path.join(imgs_dir,card_name)
        img_fns=glob(img_dir+"/*.png")
        img_base=cv2.imread(img_fns[0])
        for i in range(1000):
            img_aug = aug.augment_image(seq(image=img_base))
            cv2.imwrite(img_dir+"/"+str(i)+".png",img_aug)

# %%
imgs_dir="data/cards"

card_name = "2c"
img_dir=os.path.join(imgs_dir,card_name)
img_fns=glob(img_dir+"/*.png")
img=cv2.imread(img_fns[0])
rows,cols,ch = img.shape

plt.imshow(img)
plt.show()

# %% [markdown]
# ### Before going on, check that everything looks good
# We randomly choose and display one of the extracted card. We also draw on the card the 2 polygons defined by refCornerHL and refCornerLR. Check that the value and suit symbols are well inside the polygons. If not, check the hand-made measures : cardW, cardH, cornerXmin, cornerXmax, cornerYmin and cornerYmax

# %%
# Run a few times...
imgs_dir="data/cards"
imgs_fns=glob(imgs_dir+"/*/*.png")
img_fn=random.choice(imgs_fns)
display_img(cv2.imread(img_fn,cv2.IMREAD_UNCHANGED),polygons=[refCornerHL,refCornerLR])

# %% [markdown]
# # Finding the convex hulls
# <img src="img/convex_hull.jpg" alt="Convex hull" title="Convex hull" />
# This function 'find_hull' finds the convex hull in one of the corner of a card image.
# The convex hull is the minimal convex polygon that contains both the value and the suit symbols.
#
# When I wrote this function it needed a lot of tweaking to make it work. It works well with my deck of cards, but I can't guarantee it is adapted to other decks. Search for the keyword TWEAK in the comments to find the variable and values that may need some tweak. Some of them depend on the value of global variable 'zoom'.
# It may happen that the function can't find a valid convex hull for a card. It is not a problem, it only means that this card won't be used to generate the dataset.

# %%
def findHull(img, corner=refCornerHL, debug="no"):
    """
        Find in the zone 'corner' of image 'img' and return, the convex hull delimiting
        the value and suit symbols
        'corner' (shape (4,2)) is an array of 4 points delimiting a rectangular zone, 
        takes one of the 2 possible values : refCornerHL or refCornerLR
        debug=
    """
    
    kernel = np.ones((3,3),np.uint8)
    corner=corner.astype(np.int)

    # We will focus on the zone of 'img' delimited by 'corner'
    x1=int(corner[0][0])
    y1=int(corner[0][1])
    x2=int(corner[2][0])
    y2=int(corner[2][1])
    w=x2-x1
    h=y2-y1
    zone=img[y1:y2,x1:x2].copy()

    strange_cnt=np.zeros_like(zone)
    gray=cv2.cvtColor(zone,cv2.COLOR_BGR2GRAY)
    thld=cv2.Canny(gray,30,200)
    thld = cv2.dilate(thld,kernel,iterations=1)
    if debug!="no": cv2.imshow("thld",thld)
    
    # Find the contours
    contours,_=cv2.findContours(thld.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

    min_area=30 # We will reject contours with small area. TWEAK, 'zoom' dependant
    min_solidity=0.3 # Reject contours with a low solidity. TWEAK
    
    concat_contour=None # We will aggregate in 'concat_contour' the contours that we want to keep
    
    ok=True
    for c in contours:
        area=cv2.contourArea(c)

        hull = cv2.convexHull(c)
        hull_area = cv2.contourArea(hull)
        solidity = float(area)/hull_area
        # Determine the center of gravity (cx,cy) of the contour
        M=cv2.moments(c)
        cx=int(M['m10']/M['m00'])
        cy=int(M['m01']/M['m00'])
        #  abs(w/2-cx)<w*0.3 and abs(h/2-cy)<h*0.4 : TWEAK, the idea here is to keep only the contours which are closed to the center of the zone
        if area >= min_area and abs(w/2-cx)<w*0.3 and abs(h/2-cy)<h*0.4 and solidity>min_solidity:
            if debug != "no" :
                cv2.drawContours(zone,[c],0,(255,0,0),-1)
            if concat_contour is None:
                concat_contour=c
            else:
                concat_contour=np.concatenate((concat_contour,c))
        if debug != "no" and solidity <= min_solidity :
            print("Solidity",solidity)
            cv2.drawContours(strange_cnt,[c],0,255,2)
            cv2.imshow("Strange contours",strange_cnt)
            
     
    if concat_contour is not None:
        # At this point, we suppose that 'concat_contour' contains only the contours corresponding the value and suit symbols   
        # We can now determine the hull
        hull=cv2.convexHull(concat_contour)
        hull_area=cv2.contourArea(hull)
        # If the area of the hull is to small or too big, there may be a problem
        min_hull_area=940 # TWEAK, deck and 'zoom' dependant
        max_hull_area=2120 # TWEAK, deck and 'zoom' dependant
        if hull_area < min_hull_area or hull_area > max_hull_area: 
            ok=False
            if debug!="no":
                print("Hull area=",hull_area,"too large or too small")
        # So far, the coordinates of the hull are relative to 'zone'
        # We need the coordinates relative to the image -> 'hull_in_img' 
        hull_in_img=hull+corner[0]

    else:
        ok=False
    
    
    if debug != "no" :
        if concat_contour is not None:
            cv2.drawContours(zone,[hull],0,(0,255,0),1)
            cv2.drawContours(img,[hull_in_img],0,(0,255,0),1)
        cv2.imshow("Zone",zone)
        cv2.imshow("Image",img)
        if ok and debug!="pause_always":
            key=cv2.waitKey(1)
        else:
            key=cv2.waitKey(0)
        if key==27:
            return None
    if ok == False:
        
        return None
    
    return hull_in_img

# %%
# Test find_hull on a random card image
# debug = "no" or "pause_always" or "pause_on_pb"
# If debug!="no", you may have to press a key to continue execution after pause
debug="no" 
imgs_dir="data/cards"
imgs_fns=glob(imgs_dir+"/*/*.png")
img_fn=random.choice(imgs_fns)
print(img_fn)
img=cv2.imread(img_fn,cv2.IMREAD_UNCHANGED)

hullHL=findHull(img,refCornerHL,debug=debug)
hullLR=findHull(img,refCornerLR,debug=debug)
display_img(img,[refCornerHL,refCornerLR,hullHL,hullLR])

if debug!="no": cv2.destroyAllWindows()
# Out:
# data/cards\10c\827.png

# %% [markdown]
# ### Load all card image, calculate their convex hulls and save the whole in a pickle file (1x)
#
# The next times, we will directly load the pickle file
# The structure saved in the pickle file is a dictionnary named 'cards' of lists of triplets (img,hullHL,hullLR). The keys of the dictionnary are the card names ("Ad","10h",... so 52 entries in the dictionnary).

# %%
imgs_dir="data/cards"

cards={}
for card_name in cards_values:
        card_dir=os.path.join(imgs_dir,card_name)
        if not os.path.isdir(card_dir):
            print(f"!!! {card_dir} does not exist !!!")
            continue
        cards[card_name]=[]
        for f in glob(card_dir+"/*.png"):
            img=cv2.imread(f,cv2.IMREAD_UNCHANGED)
            hullHL=findHull(img,refCornerHL,debug="no") 
            if hullHL is None: 
                print(f"File {f} not used.")
                continue
            hullLR=findHull(img,refCornerLR,debug="no") 
            if hullLR is None: 
                print(f"File {f} not used.")
                continue
            # We store the image in "rgb" format (we don't need opencv anymore)
            img=cv2.cvtColor(img,cv2.COLOR_BGRA2RGBA)
            cards[card_name].append((img,hullHL,hullLR))
        print(f"Nb images for {card_name} : {len(cards[card_name])}")



print("Saved in :",cards_pck_fn)
pickle.dump(cards,open(cards_pck_fn,'wb'))

cv2.destroyAllWindows()
# Out:
# File data/cards\2c\107.png not used.
# File data/cards\2c\108.png not used.
# File data/cards\2c\121.png not used.
# File data/cards\2c\14.png not used.
# File data/cards\2c\147.png not used.
# File data/cards\2c\151.png not used.
# File data/cards\2c\155.png not used.
# File data/cards\2c\159.png not used.
# File data/cards\2c\163.png not used.
# File data/cards\2c\167.png not used.
# File data/cards\2c\171.png not used.
# File data/cards\2c\178.png not used.
# File data/cards\2c\191.png not used.
# File data/cards\2c\195.png not used.
# File data/cards\2c\207.png not used.
# File data/cards\2c\212.png not used.
# File data/cards\2c\222.png not used.
# File data/cards\2c\229.png not used.
# File data/cards\2c\235.png not used.
# File data/cards\2c\238.png not used.
# File data/cards\2c\240.png not used.
# File data/cards\2c\242.png not used.
# File data/cards\2c\25.png not used.
# File data/cards\2c\274.png not used.
# File data/cards\2c\278.png not used.
# File data/cards\2c\285.png not used.
# File data/cards\2c\289.png not used.
# File data/cards\2c\299.png not used.
# File data/cards\2c\311.png not used.
# File data/cards\2c\317.png not used.
# File data/cards\2c\32.png not used.
# File data/cards\2c\333.png not used.
# File data/cards\2c\337.png not used.
# File data/cards\2c\354.png not used.
# File data/cards\2c\365.png not used.
# File data/cards\2c\377.png not used.
# File data/cards\2c\378.png not used.
# File data/cards\2c\387.png not used.
# File data/cards\2c\389.png not used.
# File data/cards\2c\39.png not used.
# File data/cards\2c\411.png not used.
# File data/cards\2c\412.png not used.
# File data/cards\2c\413.png not used.
# File data/cards\2c\432.png not used.
# File data/cards\2c\434.png not used.
# File data/cards\2c\436.png not used.
# File data/cards\2c\438.png not used.
# File data/cards\2c\445.png not used.
# File data/cards\2c\451.png not used.
# File data/cards\2c\456.png not used.
# File data/cards\2c\460.png not used.
# File data/cards\2c\47.png not used.
# File data/cards\2c\471.png not used.
# File data/cards\2c\478.png not used.
# File data/cards\2c\486.png not used.
# File data/cards\2c\487.png not used.
# File data/cards\2c\50.png not used.
# File data/cards\2c\504.png not used.
# File data/cards\2c\505.png not used.
# File data/cards\2c\508.png not used.
# File data/cards\2c\542.png not used.
# File data/cards\2c\544.png not used.
# File data/cards\2c\550.png not used.
# File data/cards\2c\557.png not used.
# File data/cards\2c\572.png not used.
# File data/cards\2c\577.png not used.
# File data/cards\2c\582.png not used.
# File data/cards\2c\585.png not used.
# File data/cards\2c\590.png not used.
# File data/cards\2c\597.png not used.
# File data/cards\2c\599.png not used.
# File data/cards\2c\607.png not used.
# File data/cards\2c\614.png not used.
# File data/cards\2c\621.png not used.
# File data/cards\2c\628.png not used.
# File data/cards\2c\634.png not used.
# File data/cards\2c\641.png not used.
# File data/cards\2c\658.png not used.
# File data/cards\2c\659.png not used.
# File data/cards\2c\664.png not used.
# File data/cards\2c\707.png not used.
# File data/cards\2c\724.png not used.
# File data/cards\2c\725.png not used.
# File data/cards\2c\726.png not used.
# File data/cards\2c\727.png not used.
# File data/cards\2c\728.png not used.
# File data/cards\2c\729.png not used.
# File data/cards\2c\732.png not used.
# File data/cards\2c\734.png not used.
# File data/cards\2c\738.png not used.
# File data/cards\2c\743.png not used.
# File data/cards\2c\744.png not used.
# File data/cards\2c\75.png not used.
# File data/cards\2c\786.png not used.
# File data/cards\2c\793.png not used.
# File data/cards\2c\797.png not used.
# File data/cards\2c\809.png not used.
# File data/cards\2c\827.png not used.
# File data/cards\2c\836.png not used.
# File data/cards\2c\837.png not used.
# File data/cards\2c\843.png not used.
# File data/cards\2c\845.png not used.
# File data/cards\2c\848.png not used.
# File data/cards\2c\851.png not used.
# File data/cards\2c\854.png not used.
# File data/cards\2c\858.png not used.
# File data/cards\2c\866.png not used.
# File data/cards\2c\867.png not used.
# File data/cards\2c\884.png not used.
# File data/cards\2c\89.png not used.
# File data/cards\2c\897.png not used.
# File data/cards\2c\898.png not used.
# File data/cards\2c\911.png not used.
# File data/cards\2c\923.png not used.
# File data/cards\2c\926.png not used.
# File data/cards\2c\941.png not used.
# File data/cards\2c\945.png not used.
# File data/cards\2c\947.png not used.
# File data/cards\2c\948.png not used.
# File data/cards\2c\963.png not used.
# File data/cards\2c\973.png not used.
# File data/cards\2c\981.png not used.
# File data/cards\2c\986.png not used.
# File data/cards\2c\988.png not used.
# File data/cards\2c\989.png not used.
# Nb images for 2c : 876
# File data/cards\2s\103.png not used.
# File data/cards\2s\109.png not used.
# File data/cards\2s\110.png not used.
# File data/cards\2s\125.png not used.
# File data/cards\2s\132.png not used.
# File data/cards\2s\138.png not used.
# File data/cards\2s\14.png not used.
# File data/cards\2s\160.png not used.
# File data/cards\2s\167.png not used.
# File data/cards\2s\173.png not used.
# File data/cards\2s\174.png not used.
# File data/cards\2s\176.png not used.
# File data/cards\2s\189.png not used.
# File data/cards\2s\195.png not used.
# File data/cards\2s\198.png not used.
# File data/cards\2s\200.png not used.
# File data/cards\2s\202.png not used.
# File data/cards\2s\208.png not used.
# File data/cards\2s\209.png not used.
# File data/cards\2s\22.png not used.
# File data/cards\2s\223.png not used.
# File data/cards\2s\229.png not used.
# File data/cards\2s\235.png not used.
# File data/cards\2s\253.png not used.
# File data/cards\2s\255.png not used.
# File data/cards\2s\259.png not used.
# File data/cards\2s\266.png not used.
# File data/cards\2s\27.png not used.
# File data/cards\2s\275.png not used.
# File data/cards\2s\29.png not used.
# File data/cards\2s\290.png not used.
# File data/cards\2s\298.png not used.
# File data/cards\2s\307.png not used.
# File data/cards\2s\308.png not used.
# File data/cards\2s\320.png not used.
# File data/cards\2s\321.png not used.
# File data/cards\2s\322.png not used.
# File data/cards\2s\324.png not used.
# File data/cards\2s\347.png not used.
# File data/cards\2s\349.png not used.
# File data/cards\2s\352.png not used.
# File data/cards\2s\356.png not used.
# File data/cards\2s\357.png not used.
# File data/cards\2s\363.png not used.
# File data/cards\2s\371.png not used.
# File data/cards\2s\384.png not used.
# File data/cards\2s\391.png not used.
# File data/cards\2s\412.png not used.
# File data/cards\2s\418.png not used.
# File data/cards\2s\420.png not used.
# File data/cards\2s\425.png not used.
# File data/cards\2s\426.png not used.
# File data/cards\2s\427.png not used.
# File data/cards\2s\435.png not used.
# File data/cards\2s\437.png not used.
# File data/cards\2s\44.png not used.
# File data/cards\2s\442.png not used.
# File data/cards\2s\444.png not used.
# File data/cards\2s\45.png not used.
# File data/cards\2s\452.png not used.
# File data/cards\2s\454.png not used.
# File data/cards\2s\476.png not used.
# File data/cards\2s\480.png not used.
# File data/cards\2s\487.png not used.
# File data/cards\2s\498.png not used.
# File data/cards\2s\499.png not used.
# File data/cards\2s\50.png not used.
# File data/cards\2s\516.png not used.
# File data/cards\2s\518.png not used.
# File data/cards\2s\519.png not used.
# File data/cards\2s\521.png not used.
# File data/cards\2s\522.png not used.
# File data/cards\2s\524.png not used.
# File data/cards\2s\527.png not used.
# File data/cards\2s\533.png not used.
# File data/cards\2s\538.png not used.
# File data/cards\2s\547.png not used.
# File data/cards\2s\551.png not used.
# File data/cards\2s\554.png not used.
# File data/cards\2s\559.png not used.
# File data/cards\2s\568.png not used.
# File data/cards\2s\578.png not used.
# File data/cards\2s\582.png not used.
# File data/cards\2s\583.png not used.
# File data/cards\2s\59.png not used.
# File data/cards\2s\594.png not used.
# File data/cards\2s\603.png not used.
# File data/cards\2s\605.png not used.
# File data/cards\2s\607.png not used.
# File data/cards\2s\62.png not used.
# File data/cards\2s\638.png not used.
# File data/cards\2s\639.png not used.
# File data/cards\2s\64.png not used.
# File data/cards\2s\642.png not used.
# File data/cards\2s\645.png not used.
# File data/cards\2s\65.png not used.
# File data/cards\2s\664.png not used.
# File data/cards\2s\669.png not used.
# File data/cards\2s\694.png not used.
# File data/cards\2s\7.png not used.
# File data/cards\2s\704.png not used.
# File data/cards\2s\706.png not used.
# File data/cards\2s\715.png not used.
# File data/cards\2s\718.png not used.
# File data/cards\2s\733.png not used.
# File data/cards\2s\735.png not used.
# File data/cards\2s\74.png not used.
# File data/cards\2s\755.png not used.
# File data/cards\2s\759.png not used.
# File data/cards\2s\765.png not used.
# File data/cards\2s\767.png not used.
# File data/cards\2s\770.png not used.
# File data/cards\2s\789.png not used.
# File data/cards\2s\797.png not used.
# File data/cards\2s\824.png not used.
# File data/cards\2s\827.png not used.
# File data/cards\2s\840.png not used.
# File data/cards\2s\843.png not used.
# File data/cards\2s\85.png not used.
# File data/cards\2s\854.png not used.
# File data/cards\2s\856.png not used.
# File data/cards\2s\859.png not used.
# File data/cards\2s\862.png not used.
# File data/cards\2s\874.png not used.
# File data/cards\2s\883.png not used.
# File data/cards\2s\888.png not used.
# File data/cards\2s\892.png not used.
# File data/cards\2s\894.png not used.
# File data/cards\2s\900.png not used.
# File data/cards\2s\913.png not used.
# File data/cards\2s\921.png not used.
# File data/cards\2s\931.png not used.
# File data/cards\2s\932.png not used.
# File data/cards\2s\940.png not used.
# File data/cards\2s\962.png not used.
# File data/cards\2s\964.png not used.
# File data/cards\2s\97.png not used.
# File data/cards\2s\986.png not used.
# File data/cards\2s\995.png not used.
# File data/cards\2s\999.png not used.
# Nb images for 2s : 861
# File data/cards\4d\0.png not used.
# File data/cards\4d\1.png not used.
# File data/cards\4d\100.png not used.
# File data/cards\4d\105.png not used.
# File data/cards\4d\110.png not used.
# File data/cards\4d\115.png not used.
# File data/cards\4d\124.png not used.
# File data/cards\4d\126.png not used.
# File data/cards\4d\131.png not used.
# File data/cards\4d\136.png not used.
# File data/cards\4d\139.png not used.
# File data/cards\4d\143.png not used.
# File data/cards\4d\150.png not used.
# File data/cards\4d\157.png not used.
# File data/cards\4d\158.png not used.
# File data/cards\4d\165.png not used.
# File data/cards\4d\169.png not used.
# File data/cards\4d\171.png not used.
# File data/cards\4d\173.png not used.
# File data/cards\4d\181.png not used.
# File data/cards\4d\186.png not used.
# File data/cards\4d\189.png not used.
# File data/cards\4d\191.png not used.
# File data/cards\4d\193.png not used.
# File data/cards\4d\195.png not used.
# File data/cards\4d\206.png not used.
# File data/cards\4d\207.png not used.
# File data/cards\4d\210.png not used.
# File data/cards\4d\217.png not used.
# File data/cards\4d\222.png not used.
# File data/cards\4d\226.png not used.
# File data/cards\4d\227.png not used.
# File data/cards\4d\234.png not used.
# File data/cards\4d\236.png not used.
# File data/cards\4d\24.png not used.
# File data/cards\4d\245.png not used.
# File data/cards\4d\25.png not used.
# File data/cards\4d\252.png not used.
# File data/cards\4d\257.png not used.
# File data/cards\4d\260.png not used.
# File data/cards\4d\273.png not used.
# File data/cards\4d\277.png not used.
# File data/cards\4d\278.png not used.
# File data/cards\4d\279.png not used.
# File data/cards\4d\283.png not used.
# File data/cards\4d\288.png not used.
# File data/cards\4d\289.png not used.
# File data/cards\4d\293.png not used.
# File data/cards\4d\296.png not used.
# File data/cards\4d\301.png not used.
# File data/cards\4d\302.png not used.
# File data/cards\4d\305.png not used.
# File data/cards\4d\313.png not used.
# File data/cards\4d\316.png not used.
# File data/cards\4d\322.png not used.
# File data/cards\4d\324.png not used.
# File data/cards\4d\326.png not used.
# File data/cards\4d\329.png not used.
# File data/cards\4d\33.png not used.
# File data/cards\4d\330.png not used.
# File data/cards\4d\343.png not used.
# File data/cards\4d\346.png not used.
# File data/cards\4d\349.png not used.
# File data/cards\4d\35.png not used.
# File data/cards\4d\350.png not used.
# File data/cards\4d\359.png not used.
# File data/cards\4d\36.png not used.
# File data/cards\4d\362.png not used.
# File data/cards\4d\364.png not used.
# File data/cards\4d\366.png not used.
# File data/cards\4d\373.png not used.
# File data/cards\4d\378.png not used.
# File data/cards\4d\380.png not used.
# File data/cards\4d\382.png not used.
# File data/cards\4d\385.png not used.
# File data/cards\4d\386.png not used.
# File data/cards\4d\39.png not used.
# File data/cards\4d\392.png not used.
# File data/cards\4d\393.png not used.
# File data/cards\4d\411.png not used.
# File data/cards\4d\412.png not used.
# File data/cards\4d\420.png not used.
# File data/cards\4d\428.png not used.
# File data/cards\4d\432.png not used.
# File data/cards\4d\439.png not used.
# File data/cards\4d\440.png not used.
# File data/cards\4d\444.png not used.
# File data/cards\4d\446.png not used.
# File data/cards\4d\455.png not used.
# File data/cards\4d\460.png not used.
# File data/cards\4d\461.png not used.
# File data/cards\4d\471.png not used.
# File data/cards\4d\472.png not used.
# File data/cards\4d\481.png not used.
# File data/cards\4d\484.png not used.
# File data/cards\4d\485.png not used.
# File data/cards\4d\486.png not used.
# File data/cards\4d\487.png not used.
# File data/cards\4d\49.png not used.
# File data/cards\4d\490.png not used.
# File data/cards\4d\495.png not used.
# File data/cards\4d\496.png not used.
# File data/cards\4d\5.png not used.
# File data/cards\4d\501.png not used.
# File data/cards\4d\505.png not used.
# File data/cards\4d\517.png not used.
# File data/cards\4d\522.png not used.
# File data/cards\4d\528.png not used.
# File data/cards\4d\535.png not used.
# File data/cards\4d\536.png not used.
# File data/cards\4d\537.png not used.
# File data/cards\4d\538.png not used.
# File data/cards\4d\54.png not used.
# File data/cards\4d\542.png not used.
# File data/cards\4d\543.png not used.
# File data/cards\4d\544.png not used.
# File data/cards\4d\545.png not used.
# File data/cards\4d\546.png not used.
# File data/cards\4d\553.png not used.
# File data/cards\4d\558.png not used.
# File data/cards\4d\562.png not used.
# File data/cards\4d\570.png not used.
# File data/cards\4d\572.png not used.
# File data/cards\4d\577.png not used.
# File data/cards\4d\581.png not used.
# File data/cards\4d\583.png not used.
# File data/cards\4d\589.png not used.
# File data/cards\4d\6.png not used.
# File data/cards\4d\60.png not used.
# File data/cards\4d\600.png not used.
# File data/cards\4d\602.png not used.
# File data/cards\4d\604.png not used.
# File data/cards\4d\605.png not used.
# File data/cards\4d\61.png not used.
# File data/cards\4d\611.png not used.
# File data/cards\4d\614.png not used.
# File data/cards\4d\615.png not used.
# File data/cards\4d\617.png not used.
# File data/cards\4d\621.png not used.
# File data/cards\4d\626.png not used.
# File data/cards\4d\633.png not used.
# File data/cards\4d\635.png not used.
# File data/cards\4d\637.png not used.
# File data/cards\4d\638.png not used.
# File data/cards\4d\643.png not used.
# File data/cards\4d\645.png not used.
# File data/cards\4d\648.png not used.
# File data/cards\4d\653.png not used.
# File data/cards\4d\660.png not used.
# File data/cards\4d\667.png not used.
# File data/cards\4d\67.png not used.
# File data/cards\4d\670.png not used.
# File data/cards\4d\675.png not used.
# File data/cards\4d\679.png not used.
# File data/cards\4d\68.png not used.
# File data/cards\4d\687.png not used.
# File data/cards\4d\69.png not used.
# File data/cards\4d\691.png not used.
# File data/cards\4d\692.png not used.
# File data/cards\4d\694.png not used.
# File data/cards\4d\696.png not used.
# File data/cards\4d\697.png not used.
# File data/cards\4d\71.png not used.
# File data/cards\4d\72.png not used.
# File data/cards\4d\720.png not used.
# File data/cards\4d\728.png not used.
# File data/cards\4d\729.png not used.
# File data/cards\4d\730.png not used.
# File data/cards\4d\745.png not used.
# File data/cards\4d\747.png not used.
# File data/cards\4d\748.png not used.
# File data/cards\4d\750.png not used.
# File data/cards\4d\757.png not used.
# File data/cards\4d\764.png not used.
# File data/cards\4d\766.png not used.
# File data/cards\4d\773.png not used.
# File data/cards\4d\777.png not used.
# File data/cards\4d\778.png not used.
# File data/cards\4d\779.png not used.
# File data/cards\4d\783.png not used.
# File data/cards\4d\784.png not used.
# File data/cards\4d\793.png not used.
# File data/cards\4d\795.png not used.
# File data/cards\4d\800.png not used.
# File data/cards\4d\803.png not used.
# File data/cards\4d\804.png not used.
# File data/cards\4d\805.png not used.
# File data/cards\4d\809.png not used.
# File data/cards\4d\811.png not used.
# File data/cards\4d\812.png not used.
# File data/cards\4d\822.png not used.
# File data/cards\4d\826.png not used.
# File data/cards\4d\829.png not used.
# File data/cards\4d\830.png not used.
# File data/cards\4d\834.png not used.
# File data/cards\4d\839.png not used.
# File data/cards\4d\846.png not used.
# File data/cards\4d\85.png not used.
# File data/cards\4d\862.png not used.
# File data/cards\4d\863.png not used.
# File data/cards\4d\876.png not used.
# File data/cards\4d\881.png not used.
# File data/cards\4d\882.png not used.
# File data/cards\4d\883.png not used.
# File data/cards\4d\89.png not used.
# File data/cards\4d\891.png not used.
# File data/cards\4d\900.png not used.
# File data/cards\4d\91.png not used.
# File data/cards\4d\917.png not used.
# File data/cards\4d\918.png not used.
# File data/cards\4d\919.png not used.
# File data/cards\4d\93.png not used.
# File data/cards\4d\943.png not used.
# File data/cards\4d\951.png not used.
# File data/cards\4d\955.png not used.
# File data/cards\4d\96.png not used.
# File data/cards\4d\964.png not used.
# File data/cards\4d\966.png not used.
# File data/cards\4d\973.png not used.
# File data/cards\4d\976.png not used.
# File data/cards\4d\977.png not used.
# File data/cards\4d\979.png not used.
# File data/cards\4d\98.png not used.
# File data/cards\4d\981.png not used.
# File data/cards\4d\982.png not used.
# File data/cards\4d\998.png not used.
# Nb images for 4d : 775
# File data/cards\5d\1.png not used.
# File data/cards\5d\100.png not used.
# File data/cards\5d\103.png not used.
# File data/cards\5d\104.png not used.
# File data/cards\5d\106.png not used.
# File data/cards\5d\107.png not used.
# File data/cards\5d\109.png not used.
# File data/cards\5d\11.png not used.
# File data/cards\5d\111.png not used.
# File data/cards\5d\112.png not used.
# File data/cards\5d\113.png not used.
# File data/cards\5d\117.png not used.
# File data/cards\5d\119.png not used.
# File data/cards\5d\12.png not used.
# File data/cards\5d\120.png not used.
# File data/cards\5d\123.png not used.
# File data/cards\5d\124.png not used.
# File data/cards\5d\125.png not used.
# File data/cards\5d\128.png not used.
# File data/cards\5d\129.png not used.
# File data/cards\5d\130.png not used.
# File data/cards\5d\139.png not used.
# File data/cards\5d\142.png not used.
# File data/cards\5d\143.png not used.
# File data/cards\5d\145.png not used.
# File data/cards\5d\150.png not used.
# File data/cards\5d\152.png not used.
# File data/cards\5d\153.png not used.
# File data/cards\5d\154.png not used.
# File data/cards\5d\157.png not used.
# File data/cards\5d\158.png not used.
# File data/cards\5d\162.png not used.
# File data/cards\5d\164.png not used.
# File data/cards\5d\165.png not used.
# File data/cards\5d\167.png not used.
# File data/cards\5d\168.png not used.
# File data/cards\5d\17.png not used.
# File data/cards\5d\174.png not used.
# File data/cards\5d\175.png not used.
# File data/cards\5d\177.png not used.
# File data/cards\5d\178.png not used.
# File data/cards\5d\179.png not used.
# File data/cards\5d\18.png not used.
# File data/cards\5d\19.png not used.
# File data/cards\5d\190.png not used.
# File data/cards\5d\194.png not used.
# File data/cards\5d\196.png not used.
# File data/cards\5d\197.png not used.
# File data/cards\5d\2.png not used.
# File data/cards\5d\20.png not used.
# File data/cards\5d\200.png not used.
# File data/cards\5d\202.png not used.
# File data/cards\5d\204.png not used.
# File data/cards\5d\205.png not used.
# File data/cards\5d\207.png not used.
# File data/cards\5d\216.png not used.
# File data/cards\5d\217.png not used.
# File data/cards\5d\218.png not used.
# File data/cards\5d\219.png not used.
# File data/cards\5d\22.png not used.
# File data/cards\5d\220.png not used.
# File data/cards\5d\222.png not used.
# File data/cards\5d\223.png not used.
# File data/cards\5d\225.png not used.
# File data/cards\5d\226.png not used.
# File data/cards\5d\227.png not used.
# File data/cards\5d\229.png not used.
# File data/cards\5d\239.png not used.
# File data/cards\5d\241.png not used.
# File data/cards\5d\244.png not used.
# File data/cards\5d\245.png not used.
# File data/cards\5d\246.png not used.
# File data/cards\5d\25.png not used.
# File data/cards\5d\250.png not used.
# File data/cards\5d\251.png not used.
# File data/cards\5d\254.png not used.
# File data/cards\5d\255.png not used.
# File data/cards\5d\261.png not used.
# File data/cards\5d\262.png not used.
# File data/cards\5d\263.png not used.
# File data/cards\5d\267.png not used.
# File data/cards\5d\270.png not used.
# File data/cards\5d\271.png not used.
# File data/cards\5d\272.png not used.
# File data/cards\5d\273.png not used.
# File data/cards\5d\277.png not used.
# File data/cards\5d\279.png not used.
# File data/cards\5d\28.png not used.
# File data/cards\5d\285.png not used.
# File data/cards\5d\288.png not used.
# File data/cards\5d\290.png not used.
# File data/cards\5d\292.png not used.
# File data/cards\5d\293.png not used.
# File data/cards\5d\296.png not used.
# File data/cards\5d\297.png not used.
# File data/cards\5d\298.png not used.
# File data/cards\5d\299.png not used.
# File data/cards\5d\301.png not used.
# File data/cards\5d\303.png not used.
# File data/cards\5d\305.png not used.
# File data/cards\5d\306.png not used.
# File data/cards\5d\309.png not used.
# File data/cards\5d\311.png not used.
# File data/cards\5d\316.png not used.
# File data/cards\5d\324.png not used.
# File data/cards\5d\325.png not used.
# File data/cards\5d\326.png not used.
# File data/cards\5d\329.png not used.
# File data/cards\5d\330.png not used.
# File data/cards\5d\333.png not used.
# File data/cards\5d\335.png not used.
# File data/cards\5d\337.png not used.
# File data/cards\5d\340.png not used.
# File data/cards\5d\344.png not used.
# File data/cards\5d\347.png not used.
# File data/cards\5d\348.png not used.
# File data/cards\5d\351.png not used.
# File data/cards\5d\352.png not used.
# File data/cards\5d\353.png not used.
# File data/cards\5d\361.png not used.
# File data/cards\5d\365.png not used.
# File data/cards\5d\369.png not used.
# File data/cards\5d\37.png not used.
# File data/cards\5d\372.png not used.
# File data/cards\5d\381.png not used.
# File data/cards\5d\383.png not used.
# File data/cards\5d\386.png not used.
# File data/cards\5d\387.png not used.
# File data/cards\5d\389.png not used.
# File data/cards\5d\39.png not used.
# File data/cards\5d\390.png not used.
# File data/cards\5d\392.png not used.
# File data/cards\5d\393.png not used.
# File data/cards\5d\4.png not used.
# File data/cards\5d\400.png not used.
# File data/cards\5d\409.png not used.
# File data/cards\5d\41.png not used.
# File data/cards\5d\410.png not used.
# File data/cards\5d\412.png not used.
# File data/cards\5d\414.png not used.
# File data/cards\5d\42.png not used.
# File data/cards\5d\420.png not used.
# File data/cards\5d\421.png not used.
# File data/cards\5d\423.png not used.
# File data/cards\5d\424.png not used.
# File data/cards\5d\43.png not used.
# File data/cards\5d\432.png not used.
# File data/cards\5d\434.png not used.
# File data/cards\5d\435.png not used.
# File data/cards\5d\437.png not used.
# File data/cards\5d\441.png not used.
# File data/cards\5d\442.png not used.
# File data/cards\5d\443.png not used.
# File data/cards\5d\445.png not used.
# File data/cards\5d\455.png not used.
# File data/cards\5d\459.png not used.
# File data/cards\5d\460.png not used.
# File data/cards\5d\464.png not used.
# File data/cards\5d\467.png not used.
# File data/cards\5d\470.png not used.
# File data/cards\5d\472.png not used.
# File data/cards\5d\473.png not used.
# File data/cards\5d\475.png not used.
# File data/cards\5d\476.png not used.
# File data/cards\5d\478.png not used.
# File data/cards\5d\479.png not used.
# File data/cards\5d\48.png not used.
# File data/cards\5d\484.png not used.
# File data/cards\5d\485.png not used.
# File data/cards\5d\486.png not used.
# File data/cards\5d\487.png not used.
# File data/cards\5d\49.png not used.
# File data/cards\5d\493.png not used.
# File data/cards\5d\494.png not used.
# File data/cards\5d\496.png not used.
# File data/cards\5d\499.png not used.
# File data/cards\5d\5.png not used.
# File data/cards\5d\501.png not used.
# File data/cards\5d\506.png not used.
# File data/cards\5d\509.png not used.
# File data/cards\5d\51.png not used.
# File data/cards\5d\517.png not used.
# File data/cards\5d\518.png not used.
# File data/cards\5d\524.png not used.
# File data/cards\5d\529.png not used.
# File data/cards\5d\531.png not used.
# File data/cards\5d\532.png not used.
# File data/cards\5d\534.png not used.
# File data/cards\5d\535.png not used.
# File data/cards\5d\537.png not used.
# File data/cards\5d\541.png not used.
# File data/cards\5d\542.png not used.
# File data/cards\5d\544.png not used.
# File data/cards\5d\547.png not used.
# File data/cards\5d\548.png not used.
# File data/cards\5d\550.png not used.
# File data/cards\5d\553.png not used.
# File data/cards\5d\555.png not used.
# File data/cards\5d\558.png not used.
# File data/cards\5d\559.png not used.
# File data/cards\5d\560.png not used.
# File data/cards\5d\561.png not used.
# File data/cards\5d\565.png not used.
# File data/cards\5d\566.png not used.
# File data/cards\5d\571.png not used.
# File data/cards\5d\574.png not used.
# File data/cards\5d\576.png not used.
# File data/cards\5d\58.png not used.
# File data/cards\5d\582.png not used.
# File data/cards\5d\583.png not used.
# File data/cards\5d\586.png not used.
# File data/cards\5d\588.png not used.
# File data/cards\5d\593.png not used.
# File data/cards\5d\595.png not used.
# File data/cards\5d\596.png not used.
# File data/cards\5d\597.png not used.
# File data/cards\5d\598.png not used.
# File data/cards\5d\599.png not used.
# File data/cards\5d\600.png not used.
# File data/cards\5d\601.png not used.
# File data/cards\5d\604.png not used.
# File data/cards\5d\605.png not used.
# File data/cards\5d\608.png not used.
# File data/cards\5d\616.png not used.
# File data/cards\5d\618.png not used.
# File data/cards\5d\619.png not used.
# File data/cards\5d\62.png not used.
# File data/cards\5d\620.png not used.
# File data/cards\5d\621.png not used.
# File data/cards\5d\622.png not used.
# File data/cards\5d\627.png not used.
# File data/cards\5d\632.png not used.
# File data/cards\5d\635.png not used.
# File data/cards\5d\637.png not used.
# File data/cards\5d\638.png not used.
# File data/cards\5d\640.png not used.
# File data/cards\5d\641.png not used.
# File data/cards\5d\642.png not used.
# File data/cards\5d\644.png not used.
# File data/cards\5d\645.png not used.
# File data/cards\5d\649.png not used.
# File data/cards\5d\650.png not used.
# File data/cards\5d\653.png not used.
# File data/cards\5d\654.png not used.
# File data/cards\5d\655.png not used.
# File data/cards\5d\657.png not used.
# File data/cards\5d\659.png not used.
# File data/cards\5d\66.png not used.
# File data/cards\5d\661.png not used.
# File data/cards\5d\664.png not used.
# File data/cards\5d\667.png not used.
# File data/cards\5d\669.png not used.
# File data/cards\5d\671.png not used.
# File data/cards\5d\672.png not used.
# File data/cards\5d\68.png not used.
# File data/cards\5d\683.png not used.
# File data/cards\5d\684.png not used.
# File data/cards\5d\685.png not used.
# File data/cards\5d\692.png not used.
# File data/cards\5d\70.png not used.
# File data/cards\5d\704.png not used.
# File data/cards\5d\711.png not used.
# File data/cards\5d\714.png not used.
# File data/cards\5d\719.png not used.
# File data/cards\5d\72.png not used.
# File data/cards\5d\721.png not used.
# File data/cards\5d\722.png not used.
# File data/cards\5d\723.png not used.
# File data/cards\5d\730.png not used.
# File data/cards\5d\733.png not used.
# File data/cards\5d\735.png not used.
# File data/cards\5d\74.png not used.
# File data/cards\5d\740.png not used.
# File data/cards\5d\741.png not used.
# File data/cards\5d\744.png not used.
# File data/cards\5d\746.png not used.
# File data/cards\5d\751.png not used.
# File data/cards\5d\752.png not used.
# File data/cards\5d\754.png not used.
# File data/cards\5d\757.png not used.
# File data/cards\5d\758.png not used.
# File data/cards\5d\761.png not used.
# File data/cards\5d\762.png not used.
# File data/cards\5d\77.png not used.
# File data/cards\5d\772.png not used.
# File data/cards\5d\773.png not used.
# File data/cards\5d\774.png not used.
# File data/cards\5d\778.png not used.
# File data/cards\5d\779.png not used.
# File data/cards\5d\78.png not used.
# File data/cards\5d\780.png not used.
# File data/cards\5d\783.png not used.
# File data/cards\5d\786.png not used.
# File data/cards\5d\787.png not used.
# File data/cards\5d\790.png not used.
# File data/cards\5d\791.png not used.
# File data/cards\5d\792.png not used.
# File data/cards\5d\794.png not used.
# File data/cards\5d\796.png not used.
# File data/cards\5d\799.png not used.
# File data/cards\5d\8.png not used.
# File data/cards\5d\80.png not used.
# File data/cards\5d\807.png not used.
# File data/cards\5d\808.png not used.
# File data/cards\5d\810.png not used.
# File data/cards\5d\813.png not used.
# File data/cards\5d\817.png not used.
# File data/cards\5d\820.png not used.
# File data/cards\5d\821.png not used.
# File data/cards\5d\822.png not used.
# File data/cards\5d\826.png not used.
# File data/cards\5d\827.png not used.
# File data/cards\5d\829.png not used.
# File data/cards\5d\832.png not used.
# File data/cards\5d\835.png not used.
# File data/cards\5d\838.png not used.
# File data/cards\5d\839.png not used.
# File data/cards\5d\84.png not used.
# File data/cards\5d\840.png not used.
# File data/cards\5d\841.png not used.
# File data/cards\5d\845.png not used.
# File data/cards\5d\846.png not used.
# File data/cards\5d\850.png not used.
# File data/cards\5d\853.png not used.
# File data/cards\5d\856.png not used.
# File data/cards\5d\857.png not used.
# File data/cards\5d\860.png not used.
# File data/cards\5d\866.png not used.
# File data/cards\5d\872.png not used.
# File data/cards\5d\874.png not used.
# File data/cards\5d\879.png not used.
# File data/cards\5d\88.png not used.
# File data/cards\5d\882.png not used.
# File data/cards\5d\885.png not used.
# File data/cards\5d\886.png not used.
# File data/cards\5d\888.png not used.
# File data/cards\5d\891.png not used.
# File data/cards\5d\892.png not used.
# File data/cards\5d\894.png not used.
# File data/cards\5d\896.png not used.
# File data/cards\5d\897.png not used.
# File data/cards\5d\90.png not used.
# File data/cards\5d\901.png not used.
# File data/cards\5d\904.png not used.
# File data/cards\5d\906.png not used.
# File data/cards\5d\907.png not used.
# File data/cards\5d\908.png not used.
# File data/cards\5d\909.png not used.
# File data/cards\5d\910.png not used.
# File data/cards\5d\913.png not used.
# File data/cards\5d\916.png not used.
# File data/cards\5d\917.png not used.
# File data/cards\5d\920.png not used.
# File data/cards\5d\922.png not used.
# File data/cards\5d\93.png not used.
# File data/cards\5d\931.png not used.
# File data/cards\5d\933.png not used.
# File data/cards\5d\934.png not used.
# File data/cards\5d\936.png not used.
# File data/cards\5d\938.png not used.
# File data/cards\5d\939.png not used.
# File data/cards\5d\941.png not used.
# File data/cards\5d\943.png not used.
# File data/cards\5d\946.png not used.
# File data/cards\5d\948.png not used.
# File data/cards\5d\951.png not used.
# File data/cards\5d\952.png not used.
# File data/cards\5d\953.png not used.
# File data/cards\5d\956.png not used.
# File data/cards\5d\96.png not used.
# File data/cards\5d\960.png not used.
# File data/cards\5d\961.png not used.
# File data/cards\5d\962.png not used.
# File data/cards\5d\963.png not used.
# File data/cards\5d\964.png not used.
# File data/cards\5d\967.png not used.
# File data/cards\5d\968.png not used.
# File data/cards\5d\97.png not used.
# File data/cards\5d\971.png not used.
# File data/cards\5d\973.png not used.
# File data/cards\5d\976.png not used.
# File data/cards\5d\977.png not used.
# File data/cards\5d\978.png not used.
# File data/cards\5d\979.png not used.
# File data/cards\5d\980.png not used.
# File data/cards\5d\981.png not used.
# File data/cards\5d\982.png not used.
# File data/cards\5d\985.png not used.
# File data/cards\5d\986.png not used.
# File data/cards\5d\987.png not used.
# File data/cards\5d\988.png not used.
# File data/cards\5d\99.png not used.
# File data/cards\5d\990.png not used.
# File data/cards\5d\994.png not used.
# Nb images for 5d : 607
# File data/cards\5h\103.png not used.
# File data/cards\5h\105.png not used.
# File data/cards\5h\110.png not used.
# File data/cards\5h\116.png not used.
# File data/cards\5h\121.png not used.
# File data/cards\5h\126.png not used.
# File data/cards\5h\129.png not used.
# File data/cards\5h\13.png not used.
# File data/cards\5h\131.png not used.
# File data/cards\5h\132.png not used.
# File data/cards\5h\137.png not used.
# File data/cards\5h\138.png not used.
# File data/cards\5h\141.png not used.
# File data/cards\5h\142.png not used.
# File data/cards\5h\143.png not used.
# File data/cards\5h\144.png not used.
# File data/cards\5h\146.png not used.
# File data/cards\5h\151.png not used.
# File data/cards\5h\154.png not used.
# File data/cards\5h\156.png not used.
# File data/cards\5h\157.png not used.
# File data/cards\5h\16.png not used.
# File data/cards\5h\162.png not used.
# File data/cards\5h\164.png not used.
# File data/cards\5h\169.png not used.
# File data/cards\5h\173.png not used.
# File data/cards\5h\174.png not used.
# File data/cards\5h\178.png not used.
# File data/cards\5h\179.png not used.
# File data/cards\5h\18.png not used.
# File data/cards\5h\181.png not used.
# File data/cards\5h\183.png not used.
# File data/cards\5h\185.png not used.
# File data/cards\5h\187.png not used.
# File data/cards\5h\19.png not used.
# File data/cards\5h\194.png not used.
# File data/cards\5h\196.png not used.
# File data/cards\5h\2.png not used.
# File data/cards\5h\20.png not used.
# File data/cards\5h\200.png not used.
# File data/cards\5h\201.png not used.
# File data/cards\5h\202.png not used.
# File data/cards\5h\207.png not used.
# File data/cards\5h\208.png not used.
# File data/cards\5h\21.png not used.
# File data/cards\5h\211.png not used.
# File data/cards\5h\212.png not used.
# File data/cards\5h\214.png not used.
# File data/cards\5h\218.png not used.
# File data/cards\5h\22.png not used.
# File data/cards\5h\222.png not used.
# File data/cards\5h\224.png not used.
# File data/cards\5h\225.png not used.
# File data/cards\5h\226.png not used.
# File data/cards\5h\227.png not used.
# File data/cards\5h\23.png not used.
# File data/cards\5h\236.png not used.
# File data/cards\5h\237.png not used.
# File data/cards\5h\240.png not used.
# File data/cards\5h\242.png not used.
# File data/cards\5h\243.png not used.
# File data/cards\5h\245.png not used.
# File data/cards\5h\246.png not used.
# File data/cards\5h\25.png not used.
# File data/cards\5h\250.png not used.
# File data/cards\5h\251.png not used.
# File data/cards\5h\256.png not used.
# File data/cards\5h\258.png not used.
# File data/cards\5h\26.png not used.
# File data/cards\5h\260.png not used.
# File data/cards\5h\263.png not used.
# File data/cards\5h\265.png not used.
# File data/cards\5h\267.png not used.
# File data/cards\5h\27.png not used.
# File data/cards\5h\271.png not used.
# File data/cards\5h\272.png not used.
# File data/cards\5h\273.png not used.
# File data/cards\5h\275.png not used.
# File data/cards\5h\277.png not used.
# File data/cards\5h\278.png not used.
# File data/cards\5h\28.png not used.
# File data/cards\5h\282.png not used.
# File data/cards\5h\29.png not used.
# File data/cards\5h\291.png not used.
# File data/cards\5h\292.png not used.
# File data/cards\5h\294.png not used.
# File data/cards\5h\295.png not used.
# File data/cards\5h\297.png not used.
# File data/cards\5h\3.png not used.
# File data/cards\5h\30.png not used.
# File data/cards\5h\305.png not used.
# File data/cards\5h\306.png not used.
# File data/cards\5h\307.png not used.
# File data/cards\5h\31.png not used.
# File data/cards\5h\310.png not used.
# File data/cards\5h\312.png not used.
# File data/cards\5h\313.png not used.
# File data/cards\5h\315.png not used.
# File data/cards\5h\319.png not used.
# File data/cards\5h\320.png not used.
# File data/cards\5h\323.png not used.
# File data/cards\5h\324.png not used.
# File data/cards\5h\326.png not used.
# File data/cards\5h\328.png not used.
# File data/cards\5h\333.png not used.
# File data/cards\5h\334.png not used.
# File data/cards\5h\335.png not used.
# File data/cards\5h\339.png not used.
# File data/cards\5h\342.png not used.
# File data/cards\5h\346.png not used.
# File data/cards\5h\348.png not used.
# File data/cards\5h\349.png not used.
# File data/cards\5h\35.png not used.
# File data/cards\5h\352.png not used.
# File data/cards\5h\354.png not used.
# File data/cards\5h\355.png not used.
# File data/cards\5h\356.png not used.
# File data/cards\5h\362.png not used.
# File data/cards\5h\364.png not used.
# File data/cards\5h\365.png not used.
# File data/cards\5h\366.png not used.
# File data/cards\5h\368.png not used.
# File data/cards\5h\37.png not used.
# File data/cards\5h\371.png not used.
# File data/cards\5h\373.png not used.
# File data/cards\5h\374.png not used.
# File data/cards\5h\375.png not used.
# File data/cards\5h\377.png not used.
# File data/cards\5h\38.png not used.
# File data/cards\5h\380.png not used.
# File data/cards\5h\386.png not used.
# File data/cards\5h\388.png not used.
# File data/cards\5h\391.png not used.
# File data/cards\5h\393.png not used.
# File data/cards\5h\397.png not used.
# File data/cards\5h\399.png not used.
# File data/cards\5h\401.png not used.
# File data/cards\5h\402.png not used.
# File data/cards\5h\403.png not used.
# File data/cards\5h\405.png not used.
# File data/cards\5h\406.png not used.
# File data/cards\5h\407.png not used.
# File data/cards\5h\409.png not used.
# File data/cards\5h\41.png not used.
# File data/cards\5h\410.png not used.
# File data/cards\5h\412.png not used.
# File data/cards\5h\413.png not used.
# File data/cards\5h\414.png not used.
# File data/cards\5h\417.png not used.
# File data/cards\5h\418.png not used.
# File data/cards\5h\42.png not used.
# File data/cards\5h\421.png not used.
# File data/cards\5h\422.png not used.
# File data/cards\5h\425.png not used.
# File data/cards\5h\428.png not used.
# File data/cards\5h\43.png not used.
# File data/cards\5h\431.png not used.
# File data/cards\5h\432.png not used.
# File data/cards\5h\434.png not used.
# File data/cards\5h\435.png not used.
# File data/cards\5h\438.png not used.
# File data/cards\5h\44.png not used.
# File data/cards\5h\443.png not used.
# File data/cards\5h\444.png not used.
# File data/cards\5h\445.png not used.
# File data/cards\5h\447.png not used.
# File data/cards\5h\449.png not used.
# File data/cards\5h\45.png not used.
# File data/cards\5h\452.png not used.
# File data/cards\5h\453.png not used.
# File data/cards\5h\454.png not used.
# File data/cards\5h\455.png not used.
# File data/cards\5h\46.png not used.
# File data/cards\5h\463.png not used.
# File data/cards\5h\468.png not used.
# File data/cards\5h\469.png not used.
# File data/cards\5h\470.png not used.
# File data/cards\5h\472.png not used.
# File data/cards\5h\474.png not used.
# File data/cards\5h\477.png not used.
# File data/cards\5h\478.png not used.
# File data/cards\5h\484.png not used.
# File data/cards\5h\485.png not used.
# File data/cards\5h\490.png not used.
# File data/cards\5h\498.png not used.
# File data/cards\5h\499.png not used.
# File data/cards\5h\500.png not used.
# File data/cards\5h\501.png not used.
# File data/cards\5h\502.png not used.
# File data/cards\5h\504.png not used.
# File data/cards\5h\506.png not used.
# File data/cards\5h\507.png not used.
# File data/cards\5h\509.png not used.
# File data/cards\5h\51.png not used.
# File data/cards\5h\514.png not used.
# File data/cards\5h\520.png not used.
# File data/cards\5h\521.png not used.
# File data/cards\5h\523.png not used.
# File data/cards\5h\525.png not used.
# File data/cards\5h\526.png not used.
# File data/cards\5h\531.png not used.
# File data/cards\5h\535.png not used.
# File data/cards\5h\538.png not used.
# File data/cards\5h\540.png not used.
# File data/cards\5h\541.png not used.
# File data/cards\5h\542.png not used.
# File data/cards\5h\545.png not used.
# File data/cards\5h\546.png not used.
# File data/cards\5h\55.png not used.
# File data/cards\5h\550.png not used.
# File data/cards\5h\551.png not used.
# File data/cards\5h\552.png not used.
# File data/cards\5h\555.png not used.
# File data/cards\5h\56.png not used.
# File data/cards\5h\560.png not used.
# File data/cards\5h\561.png not used.
# File data/cards\5h\563.png not used.
# File data/cards\5h\573.png not used.
# File data/cards\5h\574.png not used.
# File data/cards\5h\575.png not used.
# File data/cards\5h\576.png not used.
# File data/cards\5h\577.png not used.
# File data/cards\5h\578.png not used.
# File data/cards\5h\579.png not used.
# File data/cards\5h\58.png not used.
# File data/cards\5h\582.png not used.
# File data/cards\5h\583.png not used.
# File data/cards\5h\584.png not used.
# File data/cards\5h\585.png not used.
# File data/cards\5h\587.png not used.
# File data/cards\5h\591.png not used.
# File data/cards\5h\594.png not used.
# File data/cards\5h\596.png not used.
# File data/cards\5h\598.png not used.
# File data/cards\5h\60.png not used.
# File data/cards\5h\604.png not used.
# File data/cards\5h\605.png not used.
# File data/cards\5h\608.png not used.
# File data/cards\5h\609.png not used.
# File data/cards\5h\613.png not used.
# File data/cards\5h\617.png not used.
# File data/cards\5h\618.png not used.
# File data/cards\5h\619.png not used.
# File data/cards\5h\620.png not used.
# File data/cards\5h\621.png not used.
# File data/cards\5h\622.png not used.
# File data/cards\5h\623.png not used.
# File data/cards\5h\625.png not used.
# File data/cards\5h\626.png not used.
# File data/cards\5h\627.png not used.
# File data/cards\5h\628.png not used.
# File data/cards\5h\63.png not used.
# File data/cards\5h\633.png not used.
# File data/cards\5h\64.png not used.
# File data/cards\5h\641.png not used.
# File data/cards\5h\643.png not used.
# File data/cards\5h\644.png not used.
# File data/cards\5h\647.png not used.
# File data/cards\5h\649.png not used.
# File data/cards\5h\653.png not used.
# File data/cards\5h\654.png not used.
# File data/cards\5h\656.png not used.
# File data/cards\5h\657.png not used.
# File data/cards\5h\661.png not used.
# File data/cards\5h\666.png not used.
# File data/cards\5h\667.png not used.
# File data/cards\5h\67.png not used.
# File data/cards\5h\671.png not used.
# File data/cards\5h\675.png not used.
# File data/cards\5h\679.png not used.
# File data/cards\5h\68.png not used.
# File data/cards\5h\680.png not used.
# File data/cards\5h\681.png not used.
# File data/cards\5h\684.png not used.
# File data/cards\5h\685.png not used.
# File data/cards\5h\688.png not used.
# File data/cards\5h\689.png not used.
# File data/cards\5h\691.png not used.
# File data/cards\5h\692.png not used.
# File data/cards\5h\697.png not used.
# File data/cards\5h\70.png not used.
# File data/cards\5h\701.png not used.
# File data/cards\5h\702.png not used.
# File data/cards\5h\705.png not used.
# File data/cards\5h\706.png not used.
# File data/cards\5h\710.png not used.
# File data/cards\5h\711.png not used.
# File data/cards\5h\714.png not used.
# File data/cards\5h\715.png not used.
# File data/cards\5h\716.png not used.
# File data/cards\5h\72.png not used.
# File data/cards\5h\720.png not used.
# File data/cards\5h\721.png not used.
# File data/cards\5h\722.png not used.
# File data/cards\5h\723.png not used.
# File data/cards\5h\726.png not used.
# File data/cards\5h\728.png not used.
# File data/cards\5h\73.png not used.
# File data/cards\5h\731.png not used.
# File data/cards\5h\732.png not used.
# File data/cards\5h\734.png not used.
# File data/cards\5h\735.png not used.
# File data/cards\5h\736.png not used.
# File data/cards\5h\737.png not used.
# File data/cards\5h\739.png not used.
# File data/cards\5h\743.png not used.
# File data/cards\5h\744.png not used.
# File data/cards\5h\747.png not used.
# File data/cards\5h\749.png not used.
# File data/cards\5h\752.png not used.
# File data/cards\5h\755.png not used.
# File data/cards\5h\756.png not used.
# File data/cards\5h\759.png not used.
# File data/cards\5h\760.png not used.
# File data/cards\5h\761.png not used.
# File data/cards\5h\763.png not used.
# File data/cards\5h\765.png not used.
# File data/cards\5h\766.png not used.
# File data/cards\5h\767.png not used.
# File data/cards\5h\77.png not used.
# File data/cards\5h\771.png not used.
# File data/cards\5h\775.png not used.
# File data/cards\5h\78.png not used.
# File data/cards\5h\780.png not used.
# File data/cards\5h\784.png not used.
# File data/cards\5h\786.png not used.
# File data/cards\5h\787.png not used.
# File data/cards\5h\79.png not used.
# File data/cards\5h\793.png not used.
# File data/cards\5h\795.png not used.
# File data/cards\5h\797.png not used.
# File data/cards\5h\799.png not used.
# File data/cards\5h\8.png not used.
# File data/cards\5h\80.png not used.
# File data/cards\5h\800.png not used.
# File data/cards\5h\801.png not used.
# File data/cards\5h\805.png not used.
# File data/cards\5h\806.png not used.
# File data/cards\5h\807.png not used.
# File data/cards\5h\81.png not used.
# File data/cards\5h\811.png not used.
# File data/cards\5h\812.png not used.
# File data/cards\5h\814.png not used.
# File data/cards\5h\818.png not used.
# File data/cards\5h\819.png not used.
# File data/cards\5h\82.png not used.
# File data/cards\5h\823.png not used.
# File data/cards\5h\828.png not used.
# File data/cards\5h\83.png not used.
# File data/cards\5h\830.png not used.
# File data/cards\5h\832.png not used.
# File data/cards\5h\833.png not used.
# File data/cards\5h\834.png not used.
# File data/cards\5h\837.png not used.
# File data/cards\5h\839.png not used.
# File data/cards\5h\841.png not used.
# File data/cards\5h\843.png not used.
# File data/cards\5h\846.png not used.
# File data/cards\5h\847.png not used.
# File data/cards\5h\848.png not used.
# File data/cards\5h\849.png not used.
# File data/cards\5h\853.png not used.
# File data/cards\5h\854.png not used.
# File data/cards\5h\856.png not used.
# File data/cards\5h\86.png not used.
# File data/cards\5h\861.png not used.
# File data/cards\5h\862.png not used.
# File data/cards\5h\866.png not used.
# File data/cards\5h\868.png not used.
# File data/cards\5h\872.png not used.
# File data/cards\5h\873.png not used.
# File data/cards\5h\877.png not used.
# File data/cards\5h\878.png not used.
# File data/cards\5h\881.png not used.
# File data/cards\5h\884.png not used.
# File data/cards\5h\889.png not used.
# File data/cards\5h\89.png not used.
# File data/cards\5h\890.png not used.
# File data/cards\5h\891.png not used.
# File data/cards\5h\894.png not used.
# File data/cards\5h\901.png not used.
# File data/cards\5h\904.png not used.
# File data/cards\5h\907.png not used.
# File data/cards\5h\911.png not used.
# File data/cards\5h\912.png not used.
# File data/cards\5h\916.png not used.
# File data/cards\5h\917.png not used.
# File data/cards\5h\919.png not used.
# File data/cards\5h\920.png not used.
# File data/cards\5h\921.png not used.
# File data/cards\5h\926.png not used.
# File data/cards\5h\928.png not used.
# File data/cards\5h\930.png not used.
# File data/cards\5h\932.png not used.
# File data/cards\5h\933.png not used.
# File data/cards\5h\935.png not used.
# File data/cards\5h\937.png not used.
# File data/cards\5h\940.png not used.
# File data/cards\5h\944.png not used.
# File data/cards\5h\945.png not used.
# File data/cards\5h\952.png not used.
# File data/cards\5h\953.png not used.
# File data/cards\5h\956.png not used.
# File data/cards\5h\957.png not used.
# File data/cards\5h\958.png not used.
# File data/cards\5h\959.png not used.
# File data/cards\5h\96.png not used.
# File data/cards\5h\961.png not used.
# File data/cards\5h\963.png not used.
# File data/cards\5h\964.png not used.
# File data/cards\5h\966.png not used.
# File data/cards\5h\968.png not used.
# File data/cards\5h\969.png not used.
# ...
# File data/cards\9h\985.png not used.
# File data/cards\9h\989.png not used.
# File data/cards\9h\99.png not used.
# File data/cards\9h\993.png not used.
# File data/cards\9h\996.png not used.
# Nb images for 9h : 724
# File data/cards\10c\0.png not used.
# File data/cards\10c\100.png not used.
# File data/cards\10c\109.png not used.
# File data/cards\10c\110.png not used.
# File data/cards\10c\118.png not used.
# File data/cards\10c\123.png not used.
# File data/cards\10c\124.png not used.
# File data/cards\10c\129.png not used.
# File data/cards\10c\13.png not used.
# File data/cards\10c\133.png not used.
# File data/cards\10c\135.png not used.
# File data/cards\10c\147.png not used.
# File data/cards\10c\151.png not used.
# File data/cards\10c\155.png not used.
# File data/cards\10c\160.png not used.
# File data/cards\10c\165.png not used.
# File data/cards\10c\180.png not used.
# File data/cards\10c\181.png not used.
# File data/cards\10c\19.png not used.
# File data/cards\10c\191.png not used.
# File data/cards\10c\194.png not used.
# File data/cards\10c\2.png not used.
# File data/cards\10c\208.png not used.
# File data/cards\10c\213.png not used.
# File data/cards\10c\215.png not used.
# File data/cards\10c\222.png not used.
# File data/cards\10c\228.png not used.
# File data/cards\10c\229.png not used.
# File data/cards\10c\238.png not used.
# File data/cards\10c\239.png not used.
# File data/cards\10c\242.png not used.
# File data/cards\10c\244.png not used.
# File data/cards\10c\246.png not used.
# File data/cards\10c\250.png not used.
# File data/cards\10c\260.png not used.
# File data/cards\10c\263.png not used.
# File data/cards\10c\276.png not used.
# File data/cards\10c\285.png not used.
# File data/cards\10c\287.png not used.
# File data/cards\10c\288.png not used.
# File data/cards\10c\326.png not used.
# File data/cards\10c\33.png not used.
# File data/cards\10c\331.png not used.
# File data/cards\10c\346.png not used.
# File data/cards\10c\348.png not used.
# File data/cards\10c\36.png not used.
# File data/cards\10c\362.png not used.
# File data/cards\10c\363.png not used.
# File data/cards\10c\37.png not used.
# File data/cards\10c\371.png not used.
# File data/cards\10c\372.png not used.
# File data/cards\10c\406.png not used.
# File data/cards\10c\409.png not used.
# File data/cards\10c\416.png not used.
# File data/cards\10c\419.png not used.
# File data/cards\10c\420.png not used.
# File data/cards\10c\434.png not used.
# File data/cards\10c\436.png not used.
# File data/cards\10c\437.png not used.
# File data/cards\10c\44.png not used.
# File data/cards\10c\445.png not used.
# File data/cards\10c\456.png not used.
# File data/cards\10c\466.png not used.
# File data/cards\10c\467.png not used.
# File data/cards\10c\468.png not used.
# File data/cards\10c\47.png not used.
# File data/cards\10c\474.png not used.
# File data/cards\10c\477.png not used.
# File data/cards\10c\489.png not used.
# File data/cards\10c\5.png not used.
# File data/cards\10c\500.png not used.
# File data/cards\10c\502.png not used.
# File data/cards\10c\515.png not used.
# File data/cards\10c\516.png not used.
# File data/cards\10c\53.png not used.
# File data/cards\10c\535.png not used.
# File data/cards\10c\537.png not used.
# File data/cards\10c\54.png not used.
# File data/cards\10c\542.png not used.
# File data/cards\10c\545.png not used.
# File data/cards\10c\547.png not used.
# File data/cards\10c\548.png not used.
# File data/cards\10c\55.png not used.
# File data/cards\10c\550.png not used.
# File data/cards\10c\553.png not used.
# File data/cards\10c\56.png not used.
# File data/cards\10c\571.png not used.
# File data/cards\10c\577.png not used.
# File data/cards\10c\581.png not used.
# File data/cards\10c\589.png not used.
# File data/cards\10c\590.png not used.
# File data/cards\10c\594.png not used.
# File data/cards\10c\6.png not used.
# File data/cards\10c\601.png not used.
# File data/cards\10c\602.png not used.
# File data/cards\10c\606.png not used.
# File data/cards\10c\609.png not used.
# File data/cards\10c\62.png not used.
# File data/cards\10c\620.png not used.
# File data/cards\10c\623.png not used.
# File data/cards\10c\629.png not used.
# File data/cards\10c\63.png not used.
# File data/cards\10c\640.png not used.
# File data/cards\10c\644.png not used.
# File data/cards\10c\649.png not used.
# File data/cards\10c\657.png not used.
# File data/cards\10c\659.png not used.
# File data/cards\10c\661.png not used.
# File data/cards\10c\693.png not used.
# File data/cards\10c\706.png not used.
# File data/cards\10c\707.png not used.
# File data/cards\10c\718.png not used.
# File data/cards\10c\72.png not used.
# File data/cards\10c\732.png not used.
# File data/cards\10c\744.png not used.
# File data/cards\10c\750.png not used.
# File data/cards\10c\758.png not used.
# File data/cards\10c\760.png not used.
# File data/cards\10c\775.png not used.
# File data/cards\10c\780.png not used.
# File data/cards\10c\781.png not used.
# File data/cards\10c\790.png not used.
# File data/cards\10c\794.png not used.
# File data/cards\10c\798.png not used.
# File data/cards\10c\8.png not used.
# File data/cards\10c\813.png not used.
# File data/cards\10c\814.png not used.
# File data/cards\10c\821.png not used.
# File data/cards\10c\832.png not used.
# File data/cards\10c\834.png not used.
# File data/cards\10c\839.png not used.
# File data/cards\10c\852.png not used.
# File data/cards\10c\863.png not used.
# File data/cards\10c\87.png not used.
# File data/cards\10c\872.png not used.
# File data/cards\10c\875.png not used.
# File data/cards\10c\88.png not used.
# File data/cards\10c\881.png not used.
# File data/cards\10c\882.png not used.
# File data/cards\10c\889.png not used.
# File data/cards\10c\896.png not used.
# File data/cards\10c\897.png not used.
# File data/cards\10c\903.png not used.
# File data/cards\10c\904.png not used.
# File data/cards\10c\908.png not used.
# File data/cards\10c\909.png not used.
# File data/cards\10c\92.png not used.
# File data/cards\10c\920.png not used.
# File data/cards\10c\923.png not used.
# File data/cards\10c\925.png not used.
# File data/cards\10c\932.png not used.
# File data/cards\10c\934.png not used.
# File data/cards\10c\946.png not used.
# File data/cards\10c\951.png not used.
# File data/cards\10c\954.png not used.
# File data/cards\10c\959.png not used.
# File data/cards\10c\967.png not used.
# File data/cards\10c\969.png not used.
# File data/cards\10c\972.png not used.
# File data/cards\10c\976.png not used.
# File data/cards\10c\984.png not used.
# File data/cards\10c\994.png not used.
# File data/cards\10c\995.png not used.
# Nb images for 10c : 838
# File data/cards\10s\10.png not used.
# File data/cards\10s\101.png not used.
# File data/cards\10s\103.png not used.
# File data/cards\10s\104.png not used.
# File data/cards\10s\105.png not used.
# File data/cards\10s\107.png not used.
# File data/cards\10s\114.png not used.
# File data/cards\10s\127.png not used.
# File data/cards\10s\128.png not used.
# File data/cards\10s\13.png not used.
# File data/cards\10s\130.png not used.
# File data/cards\10s\132.png not used.
# File data/cards\10s\138.png not used.
# File data/cards\10s\139.png not used.
# File data/cards\10s\144.png not used.
# File data/cards\10s\146.png not used.
# File data/cards\10s\152.png not used.
# File data/cards\10s\153.png not used.
# File data/cards\10s\159.png not used.
# File data/cards\10s\16.png not used.
# File data/cards\10s\160.png not used.
# File data/cards\10s\163.png not used.
# File data/cards\10s\166.png not used.
# File data/cards\10s\170.png not used.
# File data/cards\10s\171.png not used.
# File data/cards\10s\173.png not used.
# File data/cards\10s\175.png not used.
# File data/cards\10s\176.png not used.
# File data/cards\10s\18.png not used.
# File data/cards\10s\183.png not used.
# File data/cards\10s\185.png not used.
# File data/cards\10s\186.png not used.
# File data/cards\10s\187.png not used.
# File data/cards\10s\189.png not used.
# File data/cards\10s\190.png not used.
# File data/cards\10s\199.png not used.
# File data/cards\10s\2.png not used.
# File data/cards\10s\20.png not used.
# File data/cards\10s\202.png not used.
# File data/cards\10s\206.png not used.
# File data/cards\10s\207.png not used.
# File data/cards\10s\211.png not used.
# File data/cards\10s\215.png not used.
# File data/cards\10s\219.png not used.
# File data/cards\10s\221.png not used.
# File data/cards\10s\229.png not used.
# File data/cards\10s\231.png not used.
# File data/cards\10s\234.png not used.
# File data/cards\10s\240.png not used.
# File data/cards\10s\244.png not used.
# File data/cards\10s\245.png not used.
# File data/cards\10s\248.png not used.
# File data/cards\10s\249.png not used.
# File data/cards\10s\25.png not used.
# File data/cards\10s\250.png not used.
# File data/cards\10s\251.png not used.
# File data/cards\10s\256.png not used.
# File data/cards\10s\259.png not used.
# File data/cards\10s\262.png not used.
# File data/cards\10s\263.png not used.
# File data/cards\10s\265.png not used.
# File data/cards\10s\274.png not used.
# File data/cards\10s\275.png not used.
# File data/cards\10s\277.png not used.
# File data/cards\10s\284.png not used.
# File data/cards\10s\285.png not used.
# File data/cards\10s\296.png not used.
# File data/cards\10s\3.png not used.
# File data/cards\10s\301.png not used.
# File data/cards\10s\304.png not used.
# File data/cards\10s\310.png not used.
# File data/cards\10s\313.png not used.
# File data/cards\10s\318.png not used.
# File data/cards\10s\332.png not used.
# File data/cards\10s\334.png not used.
# File data/cards\10s\338.png not used.
# File data/cards\10s\341.png not used.
# File data/cards\10s\345.png not used.
# File data/cards\10s\347.png not used.
# File data/cards\10s\35.png not used.
# File data/cards\10s\350.png not used.
# File data/cards\10s\351.png not used.
# File data/cards\10s\355.png not used.
# File data/cards\10s\358.png not used.
# File data/cards\10s\359.png not used.
# File data/cards\10s\360.png not used.
# File data/cards\10s\368.png not used.
# File data/cards\10s\370.png not used.
# File data/cards\10s\377.png not used.
# File data/cards\10s\38.png not used.
# File data/cards\10s\382.png not used.
# File data/cards\10s\385.png not used.
# File data/cards\10s\391.png not used.
# File data/cards\10s\394.png not used.
# File data/cards\10s\395.png not used.
# File data/cards\10s\400.png not used.
# File data/cards\10s\402.png not used.
# File data/cards\10s\403.png not used.
# File data/cards\10s\405.png not used.
# File data/cards\10s\408.png not used.
# File data/cards\10s\410.png not used.
# File data/cards\10s\413.png not used.
# File data/cards\10s\418.png not used.
# File data/cards\10s\42.png not used.
# File data/cards\10s\422.png not used.
# File data/cards\10s\425.png not used.
# File data/cards\10s\429.png not used.
# File data/cards\10s\433.png not used.
# File data/cards\10s\436.png not used.
# File data/cards\10s\438.png not used.
# File data/cards\10s\441.png not used.
# File data/cards\10s\446.png not used.
# File data/cards\10s\45.png not used.
# File data/cards\10s\455.png not used.
# File data/cards\10s\457.png not used.
# File data/cards\10s\464.png not used.
# File data/cards\10s\466.png not used.
# File data/cards\10s\467.png not used.
# File data/cards\10s\468.png not used.
# File data/cards\10s\470.png not used.
# File data/cards\10s\474.png not used.
# File data/cards\10s\476.png not used.
# File data/cards\10s\480.png not used.
# File data/cards\10s\483.png not used.
# File data/cards\10s\493.png not used.
# File data/cards\10s\495.png not used.
# File data/cards\10s\5.png not used.
# File data/cards\10s\50.png not used.
# File data/cards\10s\503.png not used.
# File data/cards\10s\518.png not used.
# File data/cards\10s\519.png not used.
# File data/cards\10s\525.png not used.
# File data/cards\10s\527.png not used.
# File data/cards\10s\53.png not used.
# File data/cards\10s\531.png not used.
# File data/cards\10s\532.png not used.
# File data/cards\10s\539.png not used.
# File data/cards\10s\54.png not used.
# File data/cards\10s\542.png not used.
# File data/cards\10s\543.png not used.
# File data/cards\10s\546.png not used.
# File data/cards\10s\556.png not used.
# File data/cards\10s\561.png not used.
# File data/cards\10s\566.png not used.
# File data/cards\10s\567.png not used.
# File data/cards\10s\572.png not used.
# File data/cards\10s\574.png not used.
# File data/cards\10s\576.png not used.
# File data/cards\10s\577.png not used.
# File data/cards\10s\578.png not used.
# File data/cards\10s\579.png not used.
# File data/cards\10s\586.png not used.
# File data/cards\10s\590.png not used.
# File data/cards\10s\592.png not used.
# File data/cards\10s\598.png not used.
# File data/cards\10s\599.png not used.
# File data/cards\10s\613.png not used.
# File data/cards\10s\62.png not used.
# File data/cards\10s\622.png not used.
# File data/cards\10s\623.png not used.
# File data/cards\10s\63.png not used.
# File data/cards\10s\630.png not used.
# File data/cards\10s\634.png not used.
# File data/cards\10s\635.png not used.
# File data/cards\10s\638.png not used.
# File data/cards\10s\642.png not used.
# File data/cards\10s\647.png not used.
# File data/cards\10s\651.png not used.
# File data/cards\10s\654.png not used.
# File data/cards\10s\659.png not used.
# File data/cards\10s\665.png not used.
# File data/cards\10s\672.png not used.
# File data/cards\10s\681.png not used.
# File data/cards\10s\683.png not used.
# File data/cards\10s\684.png not used.
# File data/cards\10s\691.png not used.
# File data/cards\10s\693.png not used.
# File data/cards\10s\698.png not used.
# File data/cards\10s\705.png not used.
# File data/cards\10s\708.png not used.
# File data/cards\10s\734.png not used.
# File data/cards\10s\735.png not used.
# File data/cards\10s\738.png not used.
# File data/cards\10s\744.png not used.
# File data/cards\10s\745.png not used.
# File data/cards\10s\746.png not used.
# File data/cards\10s\755.png not used.
# File data/cards\10s\762.png not used.
# File data/cards\10s\765.png not used.
# File data/cards\10s\766.png not used.
# File data/cards\10s\780.png not used.
# File data/cards\10s\79.png not used.
# File data/cards\10s\790.png not used.
# File data/cards\10s\795.png not used.
# File data/cards\10s\799.png not used.
# File data/cards\10s\8.png not used.
# File data/cards\10s\80.png not used.
# File data/cards\10s\801.png not used.
# File data/cards\10s\803.png not used.
# File data/cards\10s\810.png not used.
# File data/cards\10s\816.png not used.
# File data/cards\10s\83.png not used.
# File data/cards\10s\839.png not used.
# File data/cards\10s\844.png not used.
# File data/cards\10s\847.png not used.
# File data/cards\10s\853.png not used.
# File data/cards\10s\857.png not used.
# File data/cards\10s\858.png not used.
# File data/cards\10s\863.png not used.
# File data/cards\10s\865.png not used.
# File data/cards\10s\870.png not used.
# File data/cards\10s\871.png not used.
# File data/cards\10s\874.png not used.
# File data/cards\10s\878.png not used.
# File data/cards\10s\880.png not used.
# File data/cards\10s\881.png not used.
# File data/cards\10s\883.png not used.
# File data/cards\10s\885.png not used.
# File data/cards\10s\888.png not used.
# File data/cards\10s\889.png not used.
# File data/cards\10s\892.png not used.
# File data/cards\10s\895.png not used.
# File data/cards\10s\896.png not used.
# File data/cards\10s\899.png not used.
# File data/cards\10s\906.png not used.
# File data/cards\10s\909.png not used.
# File data/cards\10s\91.png not used.
# File data/cards\10s\915.png not used.
# File data/cards\10s\921.png not used.
# File data/cards\10s\923.png not used.
# File data/cards\10s\929.png not used.
# File data/cards\10s\934.png not used.
# File data/cards\10s\937.png not used.
# File data/cards\10s\942.png not used.
# File data/cards\10s\944.png not used.
# File data/cards\10s\945.png not used.
# File data/cards\10s\946.png not used.
# File data/cards\10s\952.png not used.
# File data/cards\10s\953.png not used.
# File data/cards\10s\956.png not used.
# File data/cards\10s\961.png not used.
# File data/cards\10s\965.png not used.
# File data/cards\10s\966.png not used.
# File data/cards\10s\967.png not used.
# File data/cards\10s\969.png not used.
# File data/cards\10s\971.png not used.
# File data/cards\10s\974.png not used.
# File data/cards\10s\978.png not used.
# File data/cards\10s\979.png not used.
# File data/cards\10s\990.png not used.
# File data/cards\10s\993.png not used.
# File data/cards\10s\998.png not used.
# Nb images for 10s : 749
# Saved in : data/cards.pck

# %% [markdown]
# ### Load the cards pickle file in 'cards'
# 'cards' is an instance of the class Cards
# To get a random background image, call the method : cards.get_random() or cards.get_random(card_name) if you want a random card of a given value. Ex: cards.get_random('Ah')

# %%
class Cards():
    def __init__(self,cards_pck_fn=cards_pck_fn):
        self._cards=pickle.load(open(cards_pck_fn,'rb'))
        # self._cards is a dictionary where keys are card names (ex:'Kc') and values are lists of (img,hullHL,hullLR) 
        self._nb_cards_by_value={k:len(self._cards[k]) for k in self._cards}
        print("Nb of cards loaded per name :", self._nb_cards_by_value)
        
    def get_random(self, card_name=None, display=False):
        if card_name is None:
            card_name= random.choice(list(self._cards.keys()))
        card,hull1,hull2=self._cards[card_name][random.randint(0,self._nb_cards_by_value[card_name]-1)]
        if display:
            display_img(card,[hull1,hull2],"rgb")
        return card,card_name,hull1,hull2
    
cards = Cards()
# Out:
# Nb of cards loaded per name : {'2c': 876, '2s': 861, '4d': 775, '5d': 607, '5h': 577, '6s': 865, '7h': 676, '8c': 876, '8d': 553, '9h': 724, '10c': 838, '10s': 749}

# %%
# Test: display a random card
_=cards.get_random(display=True)
# Display a random Ace of spades
#_=cards.get_random("As",display=True)

# %% [markdown]
# # Generating a scene
# We can now generate a scene (= image of the dataset). We are considering here only 2 kinds of scene (but nothing prevents you to add more scenarios):
# 1. a scene with 2 cards: each card is randomly transformed (scaled, rotated, translated) independantly from the other;
# 2. a scene with 3 cards : the 3 cards are grouped together (a bit randomly) to form a fan, then the group is randomly transformed.
#
# |   |   |
# |---|---|
# |<img src="img/gen_2_cards.jpg" alt="Generated image with 2 cards" title="Generated image with 2 cards" />|<img src="img/gen_3_cards.jpg" alt="Generated image with 3 cards" title="Generated image with 3 cards" />|

# %% [markdown]
# ### To save bounding boxes annotations in Pascal VOC format
# http://host.robots.ox.ac.uk/pascal/VOC/voc2008/htmldoc/

# %%
xml_body_1="""<annotation>
        <folder>FOLDER</folder>
        <filename>{FILENAME}</filename>
        <path>{PATH}</path>
        <source>
                <database>Unknown</database>
        </source>
        <size>
                <width>{WIDTH}</width>
                <height>{HEIGHT}</height>
                <depth>3</depth>
        </size>
"""
xml_object=""" <object>
                <name>{CLASS}</name>
                <pose>Unspecified</pose>
                <truncated>0</truncated>
                <difficult>0</difficult>
                <bndbox>
                        <xmin>{XMIN}</xmin>
                        <ymin>{YMIN}</ymin>
                        <xmax>{XMAX}</xmax>
                        <ymax>{YMAX}</ymax>
                </bndbox>
        </object>
"""
xml_body_2="""</annotation>        
"""

def create_voc_xml(xml_file, img_file,listbba,display=False):
    with open(xml_file,"w") as f:
        f.write(xml_body_1.format(**{'FILENAME':os.path.basename(img_file), 'PATH':img_file,'WIDTH':imgW,'HEIGHT':imgH}))
        for bba in listbba:            
            f.write(xml_object.format(**{'CLASS':bba.classname,'XMIN':bba.x1,'YMIN':bba.y1,'XMAX':bba.x2,'YMAX':bba.y2}))
        f.write(xml_body_2)
        if display: print("New xml",xml_file)

# %%
# Scenario with 2 cards:
# The original image of a card has the shape (cardH,cardW,4)
# We first paste it in a zero image of shape (imgH,imgW,4) at position decalX, decalY
# so that the original image is centerd in the zero image
decalX=int((imgW-cardW)/2)
decalY=int((imgH-cardH)/2)

# Scenario with 3 cards : decal values are different
decalX3=int(imgW/2)
decalY3=int(imgH/2-cardH)

def kps_to_polygon(kps):
    """
        Convert imgaug keypoints to shapely polygon
    """
    pts=[(kp.x,kp.y) for kp in kps]
    return Polygon(pts)

def hull_to_kps(hull, decalX=decalX, decalY=decalY):
    """
        Convert hull to imgaug keypoints
    """
    # hull is a cv2.Contour, shape : Nx1x2
    kps=[ia.Keypoint(x=p[0]+decalX,y=p[1]+decalY) for p in hull.reshape(-1,2)]
    kps=ia.KeypointsOnImage(kps, shape=(imgH,imgW,3))
    return kps

def kps_to_BB(kps):
    """
        Determine imgaug bounding box from imgaug keypoints
    """
    extend=3 # To make the bounding box a little bit bigger
    kpsx=[kp.x for kp in kps.keypoints]
    minx=max(0,int(min(kpsx)-extend))
    maxx=min(imgW,int(max(kpsx)+extend))
    kpsy=[kp.y for kp in kps.keypoints]
    miny=max(0,int(min(kpsy)-extend))
    maxy=min(imgH,int(max(kpsy)+extend))
    if minx==maxx or miny==maxy:
        return None
    else:
        return ia.BoundingBox(x1=minx,y1=miny,x2=maxx,y2=maxy)


# imgaug keypoints of the bounding box of a whole card
cardKP = ia.KeypointsOnImage([
    ia.Keypoint(x=decalX,y=decalY),
    ia.Keypoint(x=decalX+cardW,y=decalY),   
    ia.Keypoint(x=decalX+cardW,y=decalY+cardH),
    ia.Keypoint(x=decalX,y=decalY+cardH)
    ], shape=(imgH,imgW,3))

# imgaug transformation for one card in scenario with 2 cards
transform_1card = iaa.Sequential([
    iaa.Affine(scale=[0.2,0.2]),
    iaa.Affine(rotate=(-180,180)),
    iaa.Affine(translate_percent={"x":(-0.25,0.25),"y":(-0.25,0.25)}),
])


# imgaug transformation for the background
scaleBg=iaa.Scale({"height": imgH, "width": imgW})

def augment(img, list_kps, seq, restart=True):
    """
        Apply augmentation 'seq' to image 'img' and keypoints 'list_kps'
        If restart is False, the augmentation has been made deterministic outside the function (used for 3 cards scenario)
    """ 
    # Make sequence deterministic
    while True:
        if restart:
            myseq=seq.to_deterministic()
        else:
            myseq=seq
        # Augment image, keypoints and bbs 
        img_aug = myseq.augment_images([img])[0]
        list_kps_aug = [myseq.augment_keypoints([kp])[0] for kp in list_kps]
        list_bbs = [kps_to_BB(list_kps_aug[1]),kps_to_BB(list_kps_aug[2])]
        valid=True
        # Check the card bounding box stays inside the image
        for bb in list_bbs:
            if bb is None or int(round(bb.x2)) >= imgW or int(round(bb.y2)) >= imgH or int(bb.x1)<=0 or int(bb.y1)<=230:
                valid=False
                break
        if valid: break
        elif not restart:
            img_aug=None
            break
                
    return img_aug,list_kps_aug,list_bbs

class BBA:  # Bounding box + annotations
    def __init__(self,bb,classname):      
        self.x1=int(round(bb.x1))
        self.y1=int(round(bb.y1))
        self.x2=int(round(bb.x2))
        self.y2=int(round(bb.y2))
        self.classname=classname
class Scene:
    def __init__(self,bg,L):
        self.listbba=[]
        transformed_images = []
        hulls_of_cards = []
        #set bg to uint if in float mode
        if (bg.dtype != "uint8"):
            bg = (bg*255).astype("uint8")

        for (img,classnb,hulla,hullb) in L: 
            
            kpsa=hull_to_kps(hulla)
            kpsb=hull_to_kps(hullb)
            #Randomly transform card. We want that card does not partially cover a corner of another card.
            # If so, we apply a new random transform to card
            while True:
                t_img=np.zeros((imgH,imgW,4),dtype=np.uint8)
                t_img[decalY:decalY+cardH,decalX:decalX+cardW,:]=img
                t_img,lkps,bbs=augment(t_img,[cardKP,kpsa,kpsb],transform_1card)
                
                mainPoly=kps_to_polygon(lkps[0].keypoints[0:4])
                valid=True
                intersect_ratio=0.1
                for smallPoly in hulls_of_cards:
                    # smallPoly1: shapely polygon of one of the hull of another card
                    a=smallPoly.area
                    # We calculate area of the intersection of card 1 corner with card 2
                    intersect=mainPoly.intersection(smallPoly)
                    ai=intersect.area
                    # If intersectio area is not small, but also not big enough, we want apply new transform to card 2
                    if 1-intersect_ratio> (a-ai)/a:
                        valid=False
                        break
                if valid: break
            for i in range(1,3):
                hulls_of_cards.append(kps_to_polygon(lkps[i].keypoints[:]))
            for bb in bbs:
                self.listbba.append(BBA(bb,classnb))
            transformed_images.append(t_img)
        
        # Construct final image of the scene by superimposing bg and transformed card images
        for i,img in enumerate(transformed_images):
            mask=np.stack([img[:,:,3]]*3,-1)
            if (i == 0):
                self.final=np.where(mask,img[:,:,0:3],scaleBg.augment_image(bg))
            else:
                self.final=np.where(mask,img[:,:,0:3],self.final)
                
    def display(self):
        fig,ax=plt.subplots(1,figsize=(8,8))
        ax.imshow(self.final)
        for bb in self.listbba:
            rect=patches.Rectangle((bb.x1,bb.y1),bb.x2-bb.x1,bb.y2-bb.y1,linewidth=1,edgecolor='b',facecolor='none')
            ax.add_patch(rect)
    def res(self):
        return self.final
    def write_files(self,save_dir,display=False):
        jpg_fn, xml_fn=give_me_filename(save_dir, ["jpg","xml"])
        plt.imsave(jpg_fn,self.final)
        if display: print("New image saved in",jpg_fn)
        create_voc_xml(xml_fn,jpg_fn, self.listbba,display=display)

#function to generate N cards with different values (N should be in [0;12])
def generate_N_cards(N):
    assert N<=len(cards_values)
    indexes_left = [i for i in range(len(cards_values))]
    L = []
    for i in range(N):
        index = np.random.choice(indexes_left)
        L.append(cards.get_random(card_name=cards_values[index]))
        indexes_left.remove(index)
    return L
# Out:
# C:\Users\ugobe\Anaconda3\envs\cv\lib\site-packages\imgaug\imgaug.py:184: DeprecationWarning: Function `Scale()` is deprecated. Use `Resize` instead. Resize has the exactly same interface as Scale.
#   warn_deprecated(msg, stacklevel=3)

# %%
bg=backgrounds.get_random()
N_CARDS = 12
L = generate_N_cards(3)

newimg=Scene(bg,L)
newimg.display()

# %%
# Test generation of a scene with 3 cards
bg=backgrounds.get_random()
img1,card_val1,hulla1,hullb1=cards.get_random()
img2,card_val2,hulla2,hullb2=cards.get_random()
img3,card_val3,hulla3,hullb3=cards.get_random()

newimg=Scene(bg,img1,card_val1,hulla1,hullb1,img2,card_val2,hulla2,hullb2,img3,card_val3,hulla3,hullb3)
newimg.display()

# %% [markdown]
# ## Generate the datasets
# Typically, you want to generate a training dataset and a validation dataset of different size and different destination directory.
# Modify the variable 'nb_cards_to_generate' and 'save_dir' accordingly

# %% [markdown]
# ### Generation of the train set

# %%
nb_cards_to_generate=2000
save_dir="data/scenes/train"

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

for i in tqdm(range(nb_cards_to_generate)):
    for N_cards in range(2,13):
        bg=backgrounds.get_random()
        L = generate_N_cards(N_cards)
        newimg=Scene(bg,L)
        newimg.write_files(save_dir)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 2000/2000 [3:29:52<00:00,  6.30s/it]

# %% [markdown]
# ### Generation of the val set

# %%
nb_cards_to_generate=200
save_dir="data/scenes/val"

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

for i in tqdm(range(nb_cards_to_generate)):
    for N_cards in range(2,13):
        bg=backgrounds.get_random()
        L = generate_N_cards(N_cards)
        newimg=Scene(bg,L)
        newimg.write_files(save_dir)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [21:17<00:00,  6.39s/it]

# %% [markdown]
# ## Generation of the test set

# %%
nb_cards_to_generate=80
save_dir="data/scenes/test"

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

for i in tqdm(range(nb_cards_to_generate)):
    for N_cards in range(2,13):
        bg=backgrounds.get_random()
        L = generate_N_cards(N_CARDS)
        newimg=Scene(bg,L)
        newimg.write_files(save_dir)

# %% [markdown]
# ## In case you want to train YOLO with the generated datasets
# YOLO cannot directly exploit the Pascal VOC annotations files. You need to convert the xml files in txt files accordingly to the syntax explained here: https://github.com/AlexeyAB/darknet#how-to-train-to-detect-your-custom-objects
# The script 'convert_voc_yolo.py' makes this conversion and also generates the txt file that contains all the images of the dataset

# %%
# !python convert_voc_yolo.py data/scenes/val data/cards.names data/val.txt
# !python convert_voc_yolo.py data/scenes/train data/cards.names data/train.txt
# Out:
# ['2c', '2s', '4d', '5d', '5h', '6s', '7h', '8c', '8d', '9h', '10c', '10s'] 12
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# ['2c', '2s', '4d', '5d', '5h', '6s', '7h', '8c', '8d', '9h', '10c', '10s'] 12
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800

# %% [markdown]
# ## Modify train.txt and val.txt from windows path to linux path

# %%
train = open("data/train.txt","r")
new_train = open("data/new_train.txt","w")
lines = train.readlines()
for line in lines:
    new_line = line[:17] + "/" + line[18:]
    new_train.write(new_line)

train.close()
new_train.close()

val = open("data/val.txt","r")
new_val = open("data/new_val.txt","w")
lines = val.readlines()
for line in lines:
    new_line = line[:15] + "/" + line[16:]
    new_val.write(new_line)

val.close()
new_val.close()
# Out:
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
